# %% [markdown]
# ## 📊 Dataset Exploration (Google Landmarks Dataset)
#
# In this section, we explored the **Google Landmarks Dataset (GLDv2)**, which contains millions of images of landmarks from around the world. Each image is labeled with:
#
# - **`id`** → Unique identifier for the image
# - **`landmark_id`** → Numerical ID assigned to the landmark
# - **`category`** → Human-readable class/category describing the landmark type
# - **`image`** → The actual image data
# - **`label`** → The landmark label mapped from `landmark_id`
#
# ---
#
# ### ✅ Steps Performed
# 1. **Loaded the Dataset**
#    - Imported the dataset containing metadata for landmark images.
#    - Verified dataset structure and checked the first few rows.
#
# 2. **Merged Landmark Names (if available)**
#    - Combined the training metadata with the `landmarks.csv` file to map `landmark_id` → landmark name.
#    - This allows us to work with *human-readable names* instead of just numerical IDs.
#
# 3. **Visualized Samples**
#    - Displayed random sample images with their `id`, `landmark_id`, `category`, and `label`.
#    - Verified that the dataset is correctly loaded and images are accessible.
#
# 4. **Extracted Categories**
#    - Pulled out all unique values from the `category` column.
#    - Sorted them to see the distinct landmark types represented in the dataset.
#
# ---
#
# ### 📂 Categories
# We found that the dataset includes the following unique **categories**:
#
# - A set of human-readable classes (such as *historical_building, museum, natural_site*, etc.).
# - These categories help us better understand the **semantic grouping** of the landmarks beyond just their IDs.
#
# This prepares us for the next stage: **EDA & Visualization**, where we will analyze the number of images per category and check dataset balance.

# %%
# Basic setup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import requests
from PIL import Image
from io import BytesIO

# For visualization
import seaborn as sns
from datasets import load_dataset
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
import io

# %% [markdown]
# ## download dataset for egypt

# %%
# !pip install -q roboflow
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.6/88.6 kB 9.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 19.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 77.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 57.0 MB/s eta 0:00:00

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="N79o2Kg5Jx1ItlvgpiNN")
project = rf.workspace("gp-j4r5m").project("augmented-iklfg")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in augmented-1 to yolov11:: 100%|██████████| 1456900/1456900 [01:22<00:00, 17636.47it/s]
# Extracting Dataset Version Zip to augmented-1 in yolov11:: 100%|██████████| 27764/27764 [00:08<00:00, 3311.62it/s]

# %%
import os
import glob
import collections
import shutil
from sklearn.model_selection import train_test_split

# %%
def get_top_classes(dataset_path, top_n=35):




    label_files = glob.glob(os.path.join(dataset_path,"**", "labels", "*.txt"), recursive=True)

    class_counts = collections.Counter()
    for lf in label_files:
        with open(lf, "r") as f:
            for line in f:
                if line.strip():
                    cid = int(line.split()[0])
                    class_counts[cid] += 1
    return [cid for cid, _ in class_counts.most_common(top_n)]

# %%
def collect_class_subset(dataset_path, selected_classes):
    all_images, all_labels = [], []



    label_files = glob.glob(os.path.join(dataset_path,"**", "labels", "*.txt"), recursive=True)


    for lf in label_files:
        with open(lf, "r") as f:
            lines = f.readlines()
            if not lines:
                continue
            cid = int(lines[0].split()[0])
            if cid in selected_classes:
                base = os.path.splitext(os.path.basename(lf))[0]


                img_candidates = glob.glob(os.path.join(dataset_path, "**", "images", base + ".*"), recursive=True)

                # img_candidates = glob.glob(os.path.join(dataset_path, "images", "**", base + ".*"), recursive=True)
                if img_candidates:
                    all_images.append(img_candidates[0])
                    all_labels.append(lf)
    return all_images, all_labels

# %%
def merge_datasets(egypt_path,output_path, top_n=35):
    # 1) احسب أعلى 20 من كل واحدة
    top20_egypt = get_top_classes(egypt_path, top_n=top_n)
    print("📌 Top 20 Egypt:", top20_egypt)

    # 2) جمع الصور والليبلز
    imgs_egypt, lbls_egypt = collect_class_subset(egypt_path, top20_egypt)

    all_images = imgs_egypt
    all_labels = lbls_egypt

    print(f"📊 Collected {len(all_images)} images total")

    # 3) Split train/test
    train_imgs, test_imgs, train_lbls, test_lbls = train_test_split(
        all_images, all_labels, test_size=0.2, random_state=42,shuffle=True
    )

    # 4) أنشئ المجلدات
    for split in ["train", "test"]:
        os.makedirs(os.path.join(output_path, "images", split), exist_ok=True)
        os.makedirs(os.path.join(output_path, "labels", split), exist_ok=True)

    # 5) نسخ train
    for img, lbl in zip(train_imgs, train_lbls):
        shutil.copy(img, os.path.join(output_path, "images", "train", os.path.basename(img)))
        shutil.copy(lbl, os.path.join(output_path, "labels", "train", os.path.basename(lbl)))

    # 6) نسخ test
    for img, lbl in zip(test_imgs, test_lbls):
        shutil.copy(img, os.path.join(output_path, "images", "test", os.path.basename(img)))
        shutil.copy(lbl, os.path.join(output_path, "labels", "test", os.path.basename(lbl)))

    print(f"✅ Done! {len(train_imgs)} train + {len(test_imgs)} test saved in {output_path}")

# %%
# ---------- تنفيذ ----------
egypt_path = "/content/augmented-1"
output_path = "/content/Merged_Top20_YOLO"

merge_datasets(egypt_path, output_path, top_n=35)
# Out:
# 📌 Top 20 Egypt: [19, 53, 24, 36, 5, 44, 41, 2, 82, 72, 34, 32, 0, 80, 62, 70, 56, 27, 69, 1, 29, 16, 66, 14, 71, 60, 23, 46, 15, 42, 13, 55, 64, 78, 38]
# 📊 Collected 10646 images total
# ✅ Done! 8516 train + 2130 test saved in /content/Merged_Top20_YOLO

# %%
import os
import glob

# number of images and classes in Merged_Top20_YOLO Dataset

dataset_path = "/content/Merged_Top20_YOLO"

img_files = glob.glob(os.path.join(dataset_path, "images", "**", "*.jpg"), recursive=True)
img_files += glob.glob(os.path.join(dataset_path, "images", "**", "*.png"), recursive=True)
num_images = len(img_files)

class_ids = set()
label_files = glob.glob(os.path.join(dataset_path, "labels", "**", "*.txt"), recursive=True)

for lf in label_files:
    with open(lf, "r") as f:
        for line in f:
            if line.strip():
                cid = int(line.split()[0])
                class_ids.add(cid)

num_classes = len(class_ids)

print(f"number of images {num_images}")
print(f"number of classes: {num_classes}")
# print(f"IDs: {sorted(class_ids)}")
# Out:
# number of images 10646
# number of classes: 35

# %%
import os
import glob

# الكلاسات المختارة
# selected_classes = [19, 53, 24, 36, 5, 44, 41, 2, 82, 72, 34, 32, 0, 80, 62, 70, 56, 27, 69, 1, 29, 16, 66, 14, 71, 60, 23, 46, 15, 42, 13, 55, 64, 78, 38]
#29, 16, 66, 14, 71, 60, 23, 46, 15, 42, 13, 55, 64, 78, 38
selected_classes = [19, 53, 24, 36, 5, 44, 41, 2, 82, 72, 34, 32, 0, 80, 62, 70, 56, 27, 69, 1, 29, 16, 66, 14, 71, 60, 23, 46, 15, 42, 13, 55, 64, 78, 38]


# اعمل mapping جديد (0 → n-1)
class_mapping = {old_id: new_id for new_id, old_id in enumerate(selected_classes)}

print("📌 Class Mapping:")
print(class_mapping)

# مسار الفولدر الجديد
dataset_path = "/content/Merged_Top20_YOLO"

# عدّل كل label files
label_files = glob.glob(os.path.join(dataset_path, "labels", "**", "*.txt"), recursive=True)

for lf in label_files:
    new_lines = []
    with open(lf, "r") as f:
        for line in f:
            parts = line.strip().split()
            if not parts:
                continue
            old_cid = int(parts[0])
            if old_cid in class_mapping:   # نعدّل لو الكلاس مختار
                parts[0] = str(class_mapping[old_cid])
                new_lines.append(" ".join(parts))
    # overwrite الملف
    with open(lf, "w") as f:
        f.write("\n".join(new_lines))

print("✅ Done! كل الكلاسات اتعملها re-index من 0 →", len(selected_classes)-1)
# Out:
# 📌 Class Mapping:
# {19: 0, 53: 1, 24: 2, 36: 3, 5: 4, 44: 5, 41: 6, 2: 7, 82: 8, 72: 9, 34: 10, 32: 11, 0: 12, 80: 13, 62: 14, 70: 15, 56: 16, 27: 17, 69: 18, 1: 19, 29: 20, 16: 21, 66: 22, 14: 23, 71: 24, 60: 25, 23: 26, 46: 27, 15: 28, 42: 29, 13: 30, 55: 31, 64: 32, 78: 33, 38: 34}
# ✅ Done! كل الكلاسات اتعملها re-index من 0 → 34

# %% [markdown]
# ## Model

# %%
# !pip install -q ultralytics
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 58.4 MB/s eta 0:00:00

# %%
from ultralytics import YOLO
#29, 16, 66, 14, 71, 60, 23, 46, 15, 42, 13, 55, 64, 78, 38
# 1: Sphinx
#   2: Great Pyramids of Giza
#   3: Mask of Tutankhamun
#   4: Bent Pyramid of King Sneferu
#   5: Pyramid of Djoser
#   6: Nefertiti
#   7: Amenhotep III and Tiye
#   8: bust of Ramesses II
#   9: Statue of King Zoser
#   10: King Thutmose III
#   11: Isis with her child
#   12: Akhenaten
#   13: Statue of Tutankhamun
#   14: Statue of Ankhesenamun
#   15: Statue of King Ramses II Luxor Temple
#   16: Standing Statue of King Ramses II
#   17: Hatshepsut face
#   18: Statue of King Ramses II Grand Egyptian Museum
#   19: Amenhotep III
#   20: Head Statue of Amenhotep iii
#   21: Colossal Statue of Queen Hatshepsut
#   22: Statue of Khafre
#   23: Colossal Statue of King Senwosret IlI
#   24: Statue of King Sety Il Holding Standards
#   25: Statue of Amenmhat I
#   26: Granite Statue of Tutankhamun
#   27: Seated Statue of Amenhotep III
#   28: Colossal Statue of Middle Kingdom King
#   29: Obelsik Tip of Hatshepsut
#   30: Colossal Statue of Hormoheb
#   31: Sphinx of Kings Ramesses ll - Merenptah
#   32: Statue of God Ptah Ramesses ll Goddess Sekhmet
#   33: Statue of Snefru
#   34: Menkaure Statue
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
yaml_content = """
path : /content/Merged_Top20_YOLO
train : /content/Merged_Top20_YOLO/images/train
val : /content/Merged_Top20_YOLO/images/test

names:
  0: Colossoi of Memnon
  1: Sphinx
  2: Great Pyramids of Giza
  3: Mask of Tutankhamun
  4: Bent Pyramid of King Sneferu
  5: Pyramid of Djoser
  6: Nefertiti
  7: Amenhotep III and Tiye
  8: bust of Ramesses II
  9: Statue of King Zoser
  10: King Thutmose III
  11: Isis with her child
  12: Akhenaten
  13: Statue of Tutankhamun
  14: Statue of Ankhesenamun
  15: Statue of King Ramses II Luxor Temple
  16: Standing Statue of King Ramses II
  17: Hatshepsut face
  18: Statue of King Ramses II Grand Egyptian Museum
  19: Amenhotep III
  20: Head Statue of Amenhotep iii
  21: Colossal Statue of Queen Hatshepsut
  22: Statue of Khafre
  23: Colossal Statue of King Senwosret IlI
  24: Statue of King Sety Il Holding Standards
  25: Statue of Amenmhat I
  26: Granite Statue of Tutankhamun
  27: Seated Statue of Amenhotep III
  28: Colossal Statue of Middle Kingdom King
  29: Obelsik Tip of Hatshepsut
  30: Colossal Statue of Hormoheb
  31: Sphinx of Kings Ramesses ll - Merenptah
  32: Statue of God Ptah Ramesses ll Goddess Sekhmet
  33: Statue of Snefru
  34: Menkaure Statue
"""

with open('/content/Merged_Top20_YOLO/data.yaml', 'w') as f:
    f.write(yaml_content)

# %%
model = YOLO('/content/last (2).pt')

# %%
result2 = model.predict(source='/content/Merged_Top20_YOLO/images/train/1_0-3-_jpg.rf.8752f5e14a64154e0a6d738a504b82fe.jpg',conf=0.25,device=[-1,-1],save=True)
# Out:
# WARNING ⚠️ Failed to initialize pynvml, GPU stats disabled: NVML Shared Library Not Found
# Searching for 2 idle GPUs with free memory >= 20.0% and free utilization >= 0.0%...
# WARNING ⚠️ NVML stats unavailable.
#
# image 1/1 /content/Merged_Top20_YOLO/images/train/1_0-3-_jpg.rf.8752f5e14a64154e0a6d738a504b82fe.jpg: 640x640 2 Great Pyramids of Gizas, 390.0ms
# Speed: 20.0ms preprocess, 390.0ms inference, 33.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict

# %%
from IPython.display import Image

# %%
Image('/content/runs/detect/predict/1_0-3-_jpg.rf.8752f5e14a64154e0a6d738a504b82fe.jpg',width=600)

# %%
import os
from ultralytics import YOLO
from PIL import Image


def crop_and_save(model, images_dir, output_dir):
    os.makedirs(output_dir, exist_ok=True)

    for img_name in os.listdir(images_dir):
        if not img_name.lower().endswith((".jpg", ".png", ".jpeg")):
            continue

        img_path = os.path.join(images_dir, img_name)

        # Run YOLO inference
        results = model(img_path)

        # افتح الصورة بالـ PIL
        img = Image.open(img_path).convert("RGB")

        # ------------------------
        # استخراج البوكسات وقص الصور
        # ------------------------
        for i, box in enumerate(results[0].boxes):
            cls_id = int(box.cls[0].item())   # class id
            x_min, y_min, x_max, y_max = box.xyxy[0].tolist()
            x_min, y_min, x_max, y_max = map(int, [x_min, y_min, x_max, y_max])

            # crop
            crop = img.crop((x_min, y_min, x_max, y_max))

            # فولدر الكلاس
            class_dir = os.path.join(output_dir, str(cls_id))
            os.makedirs(class_dir, exist_ok=True)

            # حفظ crop
            crop.save(os.path.join(class_dir, f"{img_name.replace('.jpg','')}_{i}.jpg"))

    print(f"✅ Cropping done for {images_dir} → saved to {output_dir}")



crop_and_save(model, "/content/Merged_Top20_YOLO/images/train", "egypt_cropped/train")
crop_and_save(model, "/content/Merged_Top20_YOLO/images/test", "egypt_cropped/test")
# Out:
# Streaming output truncated to the last 5000 lines.
# Speed: 4.5ms preprocess, 10.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_30_jpg.rf.2ae8dc505eac8a8e8596586d5ede559d.jpg: 640x640 1 Sphinx of Kings Ramesses ll - Merenptah, 10.3ms
# Speed: 4.1ms preprocess, 10.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_7_jpg.rf.92c5a3dd8da506e59554db3338687642.jpg: 640x640 1 Nefertiti, 11.8ms
# Speed: 4.2ms preprocess, 11.8ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_7-1-_jpg.rf.92df06ca77ffe85666799c591f40bd02.jpg: 640x640 1 Great Pyramids of Giza, 11.2ms
# Speed: 4.4ms preprocess, 11.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_12_jpg.rf.913df4a0f7499e50715c2e144824a38c.jpg: 640x640 1 Amenhotep III and Tiye, 11.1ms
# Speed: 4.5ms preprocess, 11.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_N-14_jpg.rf.a7b60ae733f0b34527619c6e41a7c728.jpg: 640x640 1 Nefertiti, 10.9ms
# Speed: 4.2ms preprocess, 10.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_A-83_jpg.rf.978aa16481be3b7b9e5e2cf016081483.jpg: 640x640 1 Akhenaten, 11.0ms
# Speed: 4.5ms preprocess, 11.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_44_jpg.rf.960b67043e947379e58e9556109f0d75.jpg: 640x640 2 Colossoi of Memnons, 10.4ms
# Speed: 4.6ms preprocess, 10.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_images-55-_jpg.rf.fa39202a2dd472cd512792fa7364e278.jpg: 640x640 1 King Thutmose III, 10.8ms
# Speed: 4.7ms preprocess, 10.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_13_jpg.rf.e406468790c935c70a871ca1b441c342.jpg: 640x640 1 Statue of God Ptah Ramesses ll Goddess Sekhmet, 10.2ms
# Speed: 4.1ms preprocess, 10.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_0_jpg.rf.d21512e6328661061def81c44cb148b6.jpg: 640x640 1 Statue of King Sety Il Holding Standards, 10.4ms
# Speed: 4.1ms preprocess, 10.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_8-1-_jpg.rf.1174c47774e88e29892bb5e6a0e9c422.jpg: 640x640 2 Colossoi of Memnons, 10.8ms
# Speed: 4.5ms preprocess, 10.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_35-1-_jpg.rf.1026548f96c2d11628e68f79c8d88c1e.jpg: 640x640 1 Bent Pyramid of King Sneferu, 10.9ms
# Speed: 4.5ms preprocess, 10.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_WhatsApp-Image-2023-05-16-at-18-50-02-2-_jpeg.rf.04c4acf61a3e02df7ce401f0183bf437.jpg: 640x640 1 Standing Statue of King Ramses II, 10.5ms
# Speed: 4.3ms preprocess, 10.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_37_jpg.rf.b6e8c92009d7b51fd0895485ca80761a.jpg: 640x640 1 Pyramid of Djoser, 10.4ms
# Speed: 4.2ms preprocess, 10.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_IMG_20250425_173022_jpg.rf.5ba1e8d3f18928c574a33a9f0db2adbf.jpg: 640x640 1 Granite Statue of Tutankhamun, 10.9ms
# Speed: 4.6ms preprocess, 10.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_A-25_jpg.rf.2d2f82f243863e1c4dde16599c13e4d3.jpg: 640x640 1 Akhenaten, 10.9ms
# Speed: 4.5ms preprocess, 10.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_IMG_20250425_173126_jpg.rf.004fa2bd605c46955f0ad691ec10390b.jpg: 640x640 1 Granite Statue of Tutankhamun, 10.4ms
# Speed: 4.3ms preprocess, 10.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_198_jpg.rf.31868b4868b3c1202bf77cbf1eb4e3a3.jpg: 640x640 1 Sphinx, 13.9ms
# Speed: 7.7ms preprocess, 13.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_61-1-_jpg.rf.681063a03672410d167576a273f1eb93.jpg: 640x640 1 Great Pyramids of Giza, 15.9ms
# Speed: 5.4ms preprocess, 15.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_33_jpg.rf.fb8e15364d4f7935bf6e23eec2acc1c0.jpg: 640x640 1 Statue of King Ramses II Luxor Temple, 11.4ms
# Speed: 4.5ms preprocess, 11.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_9-3-_jpg.rf.0d95ec1bf0cb2d22c179d442908889d4.jpg: 640x640 2 Great Pyramids of Gizas, 10.2ms
# Speed: 4.0ms preprocess, 10.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_54_jpg.rf.993b91e983cfa64f04a21ab7e9e279d3.jpg: 640x640 1 Statue of King Ramses II Grand Egyptian Museum, 10.7ms
# Speed: 5.1ms preprocess, 10.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_277_jpg.rf.34f5686f7a75d793f8eef2f252413c54.jpg: 640x640 1 Sphinx, 10.9ms
# Speed: 4.8ms preprocess, 10.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_download-6-_jpg.rf.6d7091423fd90dda74d17904ba56f46d.jpg: 640x640 1 bust of Ramesses II, 12.2ms
# Speed: 4.5ms preprocess, 12.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_IMG_1115_jpg.rf.fd6b7dfccee3473008b9449628bc5c4e.jpg: 640x640 1 Statue of Khafre, 11.9ms
# Speed: 4.5ms preprocess, 11.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_84_jpg.rf.2aa76eb62a18a00c220bf95c19fec74b.jpg: 640x640 1 Statue of King Ramses II Luxor Temple, 11.0ms
# Speed: 4.5ms preprocess, 11.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_9_jpg.rf.4f2abba8b8bfd605c3d470b7aed5e643.jpg: 640x640 1 Great Pyramids of Giza, 11.2ms
# Speed: 4.4ms preprocess, 11.2ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_images-74-_jpg.rf.8affd902a9cd8228ea6e6e14dc15a1f4.jpg: 640x640 1 Pyramid of Djoser, 10.7ms
# Speed: 3.6ms preprocess, 10.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_A-14_jpg.rf.87daa8b615d4484857329ebaa4fc0985.jpg: 640x640 1 Standing Statue of King Ramses II, 10.4ms
# Speed: 3.9ms preprocess, 10.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_download-4-_jpeg.rf.0804f7ea3d959849141f60e56e26865a.jpg: 640x640 1 Statue of Tutankhamun, 1 Statue of Ankhesenamun, 10.2ms
# Speed: 4.5ms preprocess, 10.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_30_jpg.rf.7ce836df80f34c3a76ee9de8cb6ef2d7.jpg: 640x640 1 Statue of God Ptah Ramesses ll Goddess Sekhmet, 10.7ms
# Speed: 4.4ms preprocess, 10.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_23_jpg.rf.e2ce43f9e0f9a491e46dfcf8d59c3ef8.jpg: 640x640 1 Hatshepsut face, 9.9ms
# Speed: 4.3ms preprocess, 9.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_20250414_143329_jpg.rf.1972d79b75b61f042ec6d924eba6020f.jpg: 640x640 1 Colossal Statue of Hormoheb, 10.3ms
# Speed: 4.3ms preprocess, 10.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_OIP-2023-05-28T175757-047_jpeg.rf.f365911055bf2afed1307f4d6c69402c.jpg: 640x640 1 Bent Pyramid of King Sneferu, 10.4ms
# Speed: 4.6ms preprocess, 10.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_IMG_20250425_170210_jpg.rf.f932ac0f8586f4175029f8855f73389d.jpg: 640x640 1 Statue of Amenmhat I, 10.8ms
# Speed: 4.3ms preprocess, 10.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_80_jpg.rf.5db874d182544ac32afad0a55f42af50.jpg: 640x640 1 Mask of Tutankhamun, 9.7ms
# Speed: 4.1ms preprocess, 9.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_77_jpg.rf.3f8e645deb5d46e9a69c4a17125a381f.jpg: 640x640 2 Sphinxs, 10.7ms
# Speed: 4.3ms preprocess, 10.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_8_jpg.rf.d16adc078ecc149c368d2cdc4f624fc4.jpg: 640x640 1 Colossal Statue of Queen Hatshepsut, 10.4ms
# Speed: 4.4ms preprocess, 10.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_A-48_jpg.rf.c93c195996e0f632ee6f939c557cf301.jpg: 640x640 1 Statue of Tutankhamun, 1 Statue of Ankhesenamun, 10.8ms
# Speed: 4.4ms preprocess, 10.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_62_jpg.rf.c0d9f79b791f6ee18ab51d3a22a37937.jpg: 640x640 1 Mask of Tutankhamun, 10.8ms
# Speed: 4.3ms preprocess, 10.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_A-1_jpg.rf.fc7eb37dbce1405dcbabb5f3aa0ab589.jpg: 640x640 1 Akhenaten, 11.0ms
# Speed: 4.4ms preprocess, 11.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_images-71-_jpg.rf.a4357ab5516f1825912dcb4cf8cd603d.jpg: 640x640 1 Pyramid of Djoser, 10.7ms
# Speed: 4.6ms preprocess, 10.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_59_jpg.rf.13aef9623916c42d164df48100c9366a.jpg: 640x640 1 Statue of King Ramses II Luxor Temple, 10.8ms
# Speed: 4.4ms preprocess, 10.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_download-16-_jpeg.rf.fffd2413bc283ec02d9b7f3a38009ddc.jpg: 640x640 1 Statue of King Zoser, 16.7ms
# Speed: 4.3ms preprocess, 16.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_2_jpg.rf.781100e7a0c6a4621837f584da5ce737.jpg: 640x640 1 Sphinx of Kings Ramesses ll - Merenptah, 18.4ms
# Speed: 4.6ms preprocess, 18.4ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_89_jpg.rf.7908e59bb28924e15d008a8f6cccad12.jpg: 640x640 1 Great Pyramids of Giza, 11.7ms
# Speed: 4.8ms preprocess, 11.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_101_jpg.rf.3a33b6336b8b6c33f052ad7b6f90e4ce.jpg: 640x640 1 Mask of Tutankhamun, 10.8ms
# Speed: 4.1ms preprocess, 10.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_17_jpg.rf.72f18151b96f00a9ba9fea9b3dfcccef.jpg: 640x640 1 Bent Pyramid of King Sneferu, 25.4ms
# Speed: 4.0ms preprocess, 25.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_3_jpg.rf.2920ecdc7695317e025dca85718f8e84.jpg: 640x640 2 Colossoi of Memnons, 11.0ms
# Speed: 4.4ms preprocess, 11.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_A-8_jpg.rf.8ea9be0a5be5c63c7ac960fefd971c03.jpg: 640x640 1 Statue of Tutankhamun, 1 Statue of Ankhesenamun, 12.2ms
# Speed: 4.5ms preprocess, 12.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_images-3-_jpeg.rf.3c59b1729faa30d03a24a20934e11140.jpg: 640x640 1 Hatshepsut face, 10.6ms
# Speed: 4.5ms preprocess, 10.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_images-55-_jpg.rf.f7705172f0e2aaebc930debb2e6e931a.jpg: 640x640 2 Colossoi of Memnons, 10.5ms
# Speed: 4.2ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_images-46-_jpeg.rf.2299b2fac15e25b6cf1eae2ae13f6fcd.jpg: 640x640 1 Statue of King Zoser, 11.5ms
# Speed: 6.6ms preprocess, 11.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_31_jpg.rf.5700c61865abfdfa72f775cf3dd2d3f8.jpg: 640x640 1 Colossal Statue of King Senwosret IlI, 12.3ms
# Speed: 4.5ms preprocess, 12.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_download-11-_jpg.rf.e937a9556c8dfd51b1b6a0d01f051dfd.jpg: 640x640 1 bust of Ramesses II, 11.4ms
# Speed: 4.6ms preprocess, 11.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_37_jpg.rf.63821e9daf92f2bac7f467e09f1d0d00.jpg: 640x640 1 Colossal Statue of King Senwosret IlI, 10.7ms
# Speed: 3.9ms preprocess, 10.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_images-34-1-_jpg.rf.bd01546df8acb82d1861727eae5b6445.jpg: 640x640 1 Head Statue of Amenhotep iii, 11.1ms
# Speed: 4.3ms preprocess, 11.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_70_jpg.rf.75a68be0a7651ffdafbbbd94e19117fb.jpg: 640x640 1 Great Pyramids of Giza, 10.7ms
# Speed: 4.8ms preprocess, 10.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_15_jpg.rf.e85b522740063c6a460b52bf033e3f9d.jpg: 640x640 1 Nefertiti, 10.3ms
# Speed: 4.5ms preprocess, 10.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_download-2-_jpg.rf.f88f96a15543fdc7ab116bbed26946d2.jpg: 640x640 1 Isis with her child, 12.0ms
# Speed: 5.6ms preprocess, 12.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_70_jpg.rf.0fcb36fafd0950643a0c6bb0aec398ed.jpg: 640x640 1 Statue of King Ramses II Luxor Temple, 10.2ms
# Speed: 4.0ms preprocess, 10.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_34_jpg.rf.7b001d0847c95962ea4d1a845cd9f7ab.jpg: 640x640 1 Statue of King Ramses II Grand Egyptian Museum, 11.5ms
# Speed: 4.4ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_55_jpg.rf.a870a4739acf9d85d27beb609b9465a1.jpg: 640x640 1 Statue of King Ramses II Grand Egyptian Museum, 11.0ms
# Speed: 4.7ms preprocess, 11.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_301_jpg.rf.9f8a59883787649274a22c7a93c55fdc.jpg: 640x640 1 Sphinx, 12.3ms
# Speed: 4.1ms preprocess, 12.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_A-44_jpg.rf.0d6bf838ee99f4db7f1e9ffcfaec7a23.jpg: 640x640 1 Isis with her child, 11.7ms
# Speed: 4.4ms preprocess, 11.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_images-25-_jpeg.rf.e9e2568e224418aca94049ce1b68f4a8.jpg: 640x640 1 King Thutmose III, 10.6ms
# Speed: 4.4ms preprocess, 10.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_44_jpg.rf.19c28a3211dbaf77e91de3f48d9f6195.jpg: 640x640 1 Statue of King Ramses II Luxor Temple, 10.4ms
# Speed: 4.3ms preprocess, 10.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_download-8-_jpg.rf.e608b01650216150f8585ba2e535bb9e.jpg: 640x640 1 Mask of Tutankhamun, 10.8ms
# Speed: 4.6ms preprocess, 10.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_70_jpg.rf.8ff3dde4fb7a43bb3247c1847ce671e3.jpg: 640x640 1 Mask of Tutankhamun, 13.4ms
# Speed: 4.7ms preprocess, 13.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_images-4-1-_jpg.rf.0b58a121077919c7166153cedf5cd10e.jpg: 640x640 1 Head Statue of Amenhotep iii, 16.1ms
# Speed: 4.0ms preprocess, 16.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_1_jpg.rf.cb5c76b284e96482b3f9e23065ae3e2f.jpg: 640x640 1 Colossal Statue of King Senwosret IlI, 10.8ms
# Speed: 4.0ms preprocess, 10.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_61_jpg.rf.f3c5c176da90aa3cf23b81ab44b2fe27.jpg: 640x640 1 Statue of King Ramses II Grand Egyptian Museum, 11.4ms
# Speed: 4.4ms preprocess, 11.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_A-15_jpg.rf.ae32fd8cafd3089e914d61840f1a8cba.jpg: 640x640 1 Amenhotep III, 10.4ms
# Speed: 4.7ms preprocess, 10.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_images-13-_jpg.rf.a91849603c8372ac7640991adcd9032a.jpg: 640x640 1 Head Statue of Amenhotep iii, 9.9ms
# Speed: 4.0ms preprocess, 9.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_A-12_jpg.rf.a2e48f05c32e642b8d4bfbbe93fd92e2.jpg: 640x640 1 Statue of Tutankhamun, 1 Statue of Ankhesenamun, 10.2ms
# Speed: 4.8ms preprocess, 10.2ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_47_jpg.rf.60804ccf36e3e1c71aca88e4a51b377d.jpg: 640x640 1 Pyramid of Djoser, 13.7ms
# Speed: 4.5ms preprocess, 13.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_IMG_20250425_170139_jpg.rf.4d99fe55f9b2038e355ca0b861da0754.jpg: 640x640 1 Statue of Amenmhat I, 11.1ms
# Speed: 5.2ms preprocess, 11.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_download-10-_jpeg.rf.6bf6a7201c59a040b08f0c301a646e24.jpg: 640x640 1 Sphinx, 11.2ms
# Speed: 4.5ms preprocess, 11.2ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_268_jpg.rf.dc8be8e25a71f816e6f39c981a847042.jpg: 640x640 1 Great Pyramids of Giza, 11.1ms
# Speed: 4.4ms preprocess, 11.1ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_A-10_jpg.rf.df14237fd05abc72a9c33190d2f75ac3.jpg: 640x640 1 Standing Statue of King Ramses II, 12.4ms
# Speed: 5.1ms preprocess, 12.4ms inference, 5.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_images-14-_jpg.rf.f5e767a765db284bca741fb71a103a78.jpg: 640x640 1 Nefertiti, 17.5ms
# Speed: 4.5ms preprocess, 17.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_download-6-_jpg.rf.1bed708af1e7acb012d7f864c5ac0af6.jpg: 640x640 1 bust of Ramesses II, 16.5ms
# Speed: 4.5ms preprocess, 16.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_9_jpg.rf.9e7b7de29e65b45188cd7bb291c987a8.jpg: 640x640 1 Menkaure Statue, 11.4ms
# Speed: 4.6ms preprocess, 11.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_IMG_20250425_142931_jpg.rf.8b22991cb8c901b00a33e4476e9e57da.jpg: 640x640 1 Colossal Statue of Middle Kingdom King, 13.6ms
# Speed: 8.2ms preprocess, 13.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_N-36_jpg.rf.25461ee0cb37f2a85407239e23d5ce69.jpg: 640x640 1 Nefertiti, 10.9ms
# Speed: 4.3ms preprocess, 10.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_35_jpg.rf.757e848a67dd23436cc019cc7700f39d.jpg: 640x640 1 Mask of Tutankhamun, 10.5ms
# Speed: 4.7ms preprocess, 10.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_A-45_jpg.rf.e03303c96c10242233c41a10ecaf92b6.jpg: 640x640 1 Statue of Tutankhamun, 1 Statue of Ankhesenamun, 11.9ms
# Speed: 4.8ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_56_jpg.rf.c3ee11c91f1e06171ef95ad287aca0e4.jpg: 640x640 1 Sphinx, 11.5ms
# Speed: 4.5ms preprocess, 11.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_images-12-_jpg.rf.5c15b8a8fa64c451efc04c45cb6e6b18.jpg: 640x640 1 Pyramid of Djoser, 9.9ms
# Speed: 4.3ms preprocess, 9.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_12_jpg.rf.45798383ad3bd9fec16ac3a7e9e69441.jpg: 640x640 1 Statue of King Ramses II Grand Egyptian Museum, 11.1ms
# Speed: 4.4ms preprocess, 11.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_IMG_20250425_165619_jpg.rf.1e2a3736f39587afc9a3564a26d2c912.jpg: 640x640 1 Statue of Snefru, 13.6ms
# Speed: 4.1ms preprocess, 13.6ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_images-6-_jpg.rf.5c1ec6a1f872b8fb922e1bf55b0f5915.jpg: 640x640 1 Nefertiti, 10.4ms
# Speed: 4.4ms preprocess, 10.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_images-14-_jpg.rf.3b481f9e627d10efb1cda8a729c7d126.jpg: 640x640 1 bust of Ramesses II, 10.4ms
# Speed: 4.5ms preprocess, 10.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_8-3-_jpg.rf.f992c02dde64adfb4af1750792092e30.jpg: 640x640 1 Great Pyramids of Giza, 10.6ms
# Speed: 4.4ms preprocess, 10.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_90_jpg.rf.9192ea435122c1c0fb17ae07646b2fa3.jpg: 640x640 1 Mask of Tutankhamun, 14.1ms
# Speed: 7.0ms preprocess, 14.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_download-14-_jpg.rf.4e39a2d02d8222cdca862735113ada70.jpg: 640x640 1 bust of Ramesses II, 10.9ms
# Speed: 8.0ms preprocess, 10.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_IMG_20250425_150157_1_jpg.rf.47431bd3d501173f0f2a85af87b548f0.jpg: 640x640 1 Obelsik Tip of Hatshepsut, 10.1ms
# Speed: 7.1ms preprocess, 10.1ms inference, 5.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_IMG_1103_jpg.rf.a464480d0cf3e2c8bf878bddf9033d0c.jpg: 640x640 1 Statue of Khafre, 10.7ms
# Speed: 4.1ms preprocess, 10.7ms inference, 4.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_20-1-_jpg.rf.f24d6abc61fe96b149e67bccc204175a.jpg: 640x640 1 Colossoi of Memnon, 10.9ms
# Speed: 4.3ms preprocess, 10.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_WhatsApp-Image-2023-05-16-at-18-49-49-1-_jpeg.rf.ef980e6ff6fd3fc93b395d80720b6baf.jpg: 640x640 1 Standing Statue of King Ramses II, 10.3ms
# Speed: 4.2ms preprocess, 10.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_18-1-_jpg.rf.369f1d4064e1bdfd407b87ef2e0141e0.jpg: 640x640 1 Mask of Tutankhamun, 10.4ms
# Speed: 4.5ms preprocess, 10.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_images-42-_jpg.rf.1fedd5e81b6212bb7d378d136b7b6ee8.jpg: 640x640 1 Bent Pyramid of King Sneferu, 11.8ms
# Speed: 4.5ms preprocess, 11.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_A-45_jpg.rf.203edbb4406eaa1948817f507475fcad.jpg: 640x640 1 Isis with her child, 12.2ms
# Speed: 6.0ms preprocess, 12.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_36_jpg.rf.644dfc4cdf3018a59d97b66eae9fe59f.jpg: 640x640 1 Bent Pyramid of King Sneferu, 10.5ms
# Speed: 4.2ms preprocess, 10.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_Kairo_Museum_Sitzstatue_Djoser_01_jpg.rf.e1a35424994b0e88b73a2ac60e1c48bb.jpg: 640x640 1 Statue of King Zoser, 10.6ms
# Speed: 4.3ms preprocess, 10.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_286_jpg.rf.179fb73397a3984339ebc5f023cb8753.jpg: 640x640 1 Great Pyramids of Giza, 10.6ms
# Speed: 4.4ms preprocess, 10.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_download-13-_jpg.rf.32355a09b86efc2ac1c95c34be09b456.jpg: 640x640 1 Bent Pyramid of King Sneferu, 10.3ms
# Speed: 4.4ms preprocess, 10.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_images-6-_jpg.rf.3f3a2d520be1a021dda1a697b41abc2b.jpg: 640x640 2 Colossoi of Memnons, 10.2ms
# Speed: 4.2ms preprocess, 10.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_9_jpg.rf.956c252c069fcf5993b5c3cb2a5fabcb.jpg: 640x640 1 Amenhotep III and Tiye, 10.2ms
# Speed: 4.4ms preprocess, 10.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_11_jpg.rf.048bf7869c561819d3cc87153a341173.jpg: 640x640 1 Statue of God Ptah Ramesses ll Goddess Sekhmet, 10.5ms
# Speed: 4.3ms preprocess, 10.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_36_jpg.rf.2508bd9acfcf14360c0c7cfcc0cb10a3.jpg: 640x640 1 Amenhotep III and Tiye, 10.4ms
# Speed: 4.2ms preprocess, 10.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_IMG_20250425_165636_jpg.rf.10d6c3241e716473410a08b52ca94820.jpg: 640x640 1 Statue of Snefru, 10.8ms
# Speed: 4.4ms preprocess, 10.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_112_jpg.rf.63107c44fd6b321f8e50c674f4d90b2f.jpg: 640x640 1 Mask of Tutankhamun, 11.5ms
# Speed: 4.4ms preprocess, 11.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_images-10-_jpg.rf.85ec789649b626209ce765e5a9ed2ff6.jpg: 640x640 1 Isis with her child, 10.5ms
# Speed: 4.3ms preprocess, 10.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_106_jpg.rf.dab39ee6f5b5f7b4e44c96acf2333955.jpg: 640x640 2 Sphinxs, 10.3ms
# Speed: 4.3ms preprocess, 10.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_images-68-_jpg.rf.5eeeda937011bc0edd48037320f451f6.jpg: 640x640 1 Pyramid of Djoser, 10.6ms
# Speed: 4.5ms preprocess, 10.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_A-39_jpg.rf.10aa502f6f3a9c3e1fd8e24de6f98e6d.jpg: 640x640 1 Standing Statue of King Ramses II, 10.8ms
# Speed: 4.2ms preprocess, 10.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_6-1-_jpg.rf.3e9b65c8dcd8e46ba7850c9f3766a92d.jpg: 640x640 3 Sphinxs, 10.2ms
# Speed: 4.4ms preprocess, 10.2ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_IMG_20250425_170423_jpg.rf.491834de94ed9c19bcdd5befa39f3985.jpg: 640x640 1 Statue of Amenmhat I, 11.5ms
# Speed: 7.3ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_69_jpg.rf.50205b7d243d2b8fd47bb62e32cc36ce.jpg: 640x640 1 Amenhotep III and Tiye, 11.0ms
# Speed: 4.4ms preprocess, 11.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_A-57_jpg.rf.ccc1eb5448ccf295a9d11a92f98b4b2a.jpg: 640x640 1 Statue of Tutankhamun, 1 Statue of Ankhesenamun, 10.8ms
# Speed: 4.3ms preprocess, 10.8ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_images-20-_jpeg.rf.73a6362872b7e5f7b1bd350140001f6b.jpg: 640x640 1 Statue of Tutankhamun, 1 Statue of Ankhesenamun, 12.2ms
# Speed: 4.4ms preprocess, 12.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_70_jpg.rf.1bedbf9f5ec6623d6083b16b4c2d7e79.jpg: 640x640 2 Colossoi of Memnons, 10.0ms
# Speed: 4.4ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_85_jpg.rf.b7262d4e2dc539615f55bd2803409a2c.jpg: 640x640 1 Mask of Tutankhamun, 10.3ms
# Speed: 4.2ms preprocess, 10.3ms inference, 6.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_IMG_20250425_143334_jpg.rf.57b646ff556d3a4a4a24c9259a5abf9f.jpg: 640x640 1 Seated Statue of Amenhotep III, 16.6ms
# Speed: 4.2ms preprocess, 16.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_IMG_20250425_170210_jpg.rf.fb533c7b50c324d091902f42a03e3dcc.jpg: 640x640 1 Statue of Amenmhat I, 13.0ms
# Speed: 4.3ms preprocess, 13.0ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_IMG_20250425_150048_jpg.rf.9505ff03a852d0088a43ceb28f65d0bb.jpg: 640x640 1 Obelsik Tip of Hatshepsut, 12.6ms
# Speed: 4.4ms preprocess, 12.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_images-63-_jpg.rf.0aa08d62d5294d75e1b117e926b4b225.jpg: 640x640 1 Mask of Tutankhamun, 10.6ms
# Speed: 4.7ms preprocess, 10.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_2-_jpg.rf.32c34b01ed3ee2b72e5108a88f09abfa.jpg: 640x640 1 King Thutmose III, 9.8ms
# Speed: 4.3ms preprocess, 9.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_18_jpg.rf.01c8d669700827a5238bc5475d8d0ddf.jpg: 640x640 1 Statue of King Ramses II Luxor Temple, 10.7ms
# Speed: 4.1ms preprocess, 10.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_IMG_20250425_143049_jpg.rf.e72bac23349dbba568e17a342d86a6cd.jpg: 640x640 1 Colossal Statue of Middle Kingdom King, 9.5ms
# Speed: 4.3ms preprocess, 9.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_images-45-_jpeg.rf.2b00c40cc5b8a083bc5d7efb0bc172e6.jpg: 640x640 1 King Thutmose III, 9.7ms
# Speed: 4.3ms preprocess, 9.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_images-25-_jpg.rf.4d3ff3f37857336428bfa1e07f94ec6f.jpg: 640x640 1 Nefertiti, 10.6ms
# Speed: 4.3ms preprocess, 10.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_OIP-53-_jpeg.rf.60a90b7fd4a35c04d878fb381efb1ca9.jpg: 640x640 1 Bent Pyramid of King Sneferu, 9.6ms
# Speed: 4.4ms preprocess, 9.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_8_jpg.rf.68c6bd75303fe93ed8e1573d7d5803f2.jpg: 640x640 1 bust of Ramesses II, 10.0ms
# Speed: 4.4ms preprocess, 10.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_231_jpg.rf.e134d94b2e07d1635ab67c1e8e22dc8f.jpg: 640x640 1 Sphinx, 11.2ms
# Speed: 4.4ms preprocess, 11.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_170_jpg.rf.4d0c1cb3011081164b64099f67e64cdd.jpg: 640x640 1 Sphinx, 10.5ms
# Speed: 4.4ms preprocess, 10.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_27_jpg.rf.90312d4b16e3c09c7bda35541dc65d09.jpg: 640x640 1 Statue of God Ptah Ramesses ll Goddess Sekhmet, 10.5ms
# Speed: 4.3ms preprocess, 10.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_images-21-_jpeg.rf.e8179e07ce88dbf388a7eed77dd3a623.jpg: 640x640 1 King Thutmose III, 10.3ms
# Speed: 4.3ms preprocess, 10.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_IMG_1121_jpg.rf.d96de477f91a9001a0c5c96e8f91e869.jpg: 640x640 1 Statue of Khafre, 10.3ms
# Speed: 4.5ms preprocess, 10.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_Seated_statue_of_Amenhotep_III-_British_Museum_jpg.rf.6fed0c88f10069adb72167261cc0ec05.jpg: 640x640 1 Amenhotep III, 1 Granite Statue of Tutankhamun, 9.7ms
# Speed: 4.2ms preprocess, 9.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_A-41_jpg.rf.33c0e1d39dca684c2d071391a5669469.jpg: 640x640 1 Akhenaten, 13.6ms
# Speed: 4.1ms preprocess, 13.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_istockphoto-153653802-612x612_jpg.rf.923f4726f524541490174b3b82439aa7.jpg: 640x640 1 Bent Pyramid of King Sneferu, 16.5ms
# Speed: 4.4ms preprocess, 16.5ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_A-47_jpg.rf.65d9bfc7928f5513cb43dc341defdc23.jpg: 640x640 1 Standing Statue of King Ramses II, 18.7ms
# Speed: 4.5ms preprocess, 18.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_11_jpg.rf.9c9efd10306dfaf8e0799953f91baf7f.jpg: 640x640 1 Colossal Statue of King Senwosret IlI, 16.4ms
# Speed: 7.0ms preprocess, 16.4ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_fzvl34doqe1d1_jpeg.rf.1936b6dd0d9f62b52cb8e36f96cd7e25.jpg: 640x640 1 Amenhotep III, 17.8ms
# Speed: 7.8ms preprocess, 17.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_images-33-_jpg.rf.e307f8d8914ae1cc27b07a9067185445.jpg: 640x640 1 bust of Ramesses II, 10.8ms
# Speed: 4.2ms preprocess, 10.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_images-11-_jpg.rf.e7d7b22f3443dffe5935d423f91c302c.jpg: 640x640 1 bust of Ramesses II, 14.4ms
# Speed: 4.3ms preprocess, 14.4ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_images-34-_jpg.rf.43881d764f70f534bbe13e02756675df.jpg: 640x640 1 Pyramid of Djoser, 14.3ms
# Speed: 4.5ms preprocess, 14.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_2_jpg.rf.db37f4721e323b53465d850b7cefc3ef.jpg: 640x640 (no detections), 17.8ms
# Speed: 7.1ms preprocess, 17.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_243_jpg.rf.75fa2da5f531ba96b03f63b4388413bc.jpg: 640x640 2 Sphinxs, 12.8ms
# Speed: 4.5ms preprocess, 12.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_WhatsApp-Image-2023-05-16-at-18-49-38-1-_jpeg.rf.f8f3d06274ea8bb01bfbaa4a1df803c8.jpg: 640x640 1 Standing Statue of King Ramses II, 10.3ms
# Speed: 4.5ms preprocess, 10.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_IMG_1069_jpg.rf.65b2b07a023587f4d4232efc9cc6ec2f.jpg: 640x640 1 Statue of Khafre, 10.2ms
# Speed: 4.0ms preprocess, 10.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_12_jpg.rf.a76aaed49821d2dd468463abd8dfe50c.jpg: 640x640 1 Statue of King Ramses II Luxor Temple, 14.3ms
# Speed: 4.0ms preprocess, 14.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_images-5-1-_jpg.rf.2baba2855441acba736681915a5ac509.jpg: 640x640 1 Head Statue of Amenhotep iii, 13.7ms
# Speed: 4.4ms preprocess, 13.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_137_jpg.rf.c17c2d1856fb476d4e1253a8b766a9b2.jpg: 640x640 1 Great Pyramids of Giza, 10.4ms
# Speed: 4.4ms preprocess, 10.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_70-1-_jpg.rf.c02c5fc557dab4bf18c241f3652c1f37.jpg: 640x640 2 Colossoi of Memnons, 9.8ms
# Speed: 4.5ms preprocess, 9.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_6-1-_jpg.rf.c96cd359488bb39308be0b4ae75b2cdc.jpg: 640x640 2 Colossoi of Memnons, 17.0ms
# Speed: 4.2ms preprocess, 17.0ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_17-1-_jpg.rf.df0069a24bc097fff799ab71fe8e1869.jpg: 640x640 1 Great Pyramids of Giza, 10.8ms
# Speed: 7.1ms preprocess, 10.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_images-44-_jpeg.rf.9e02d9ebc17f2706ea499fb9a58e35ab.jpg: 640x640 1 Statue of King Zoser, 17.3ms
# Speed: 4.2ms preprocess, 17.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_A-11_jpg.rf.232916ad6f382bfd58a767a7c4980877.jpg: 640x640 1 Isis with her child, 16.3ms
# Speed: 4.1ms preprocess, 16.3ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_istockphoto-153653802-612x612_jpg.rf.3bab7589eb1059262af5befea26e46ef.jpg: 640x640 1 Bent Pyramid of King Sneferu, 13.4ms
# Speed: 6.3ms preprocess, 13.4ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_60_jpg.rf.dca007438cd74a24f6109dca731bdb77.jpg: 640x640 1 Hatshepsut face, 15.1ms
# Speed: 7.5ms preprocess, 15.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_images-18-_jpg.rf.2bf210945841c8a979af4751fe32b4a1.jpg: 640x640 3 Colossoi of Memnons, 12.4ms
# Speed: 5.7ms preprocess, 12.4ms inference, 4.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_A-50_jpg.rf.5541f5f6e8f29a12343298ff202bc3b0.jpg: 640x640 1 Isis with her child, 10.0ms
# Speed: 4.4ms preprocess, 10.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_A-35_jpg.rf.6728bea59c08cbcc8921dfdf47383ec9.jpg: 640x640 1 Statue of Tutankhamun, 1 Statue of Ankhesenamun, 13.8ms
# Speed: 4.5ms preprocess, 13.8ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_89_jpg.rf.e87de30451115568276ee7b2fefb66e8.jpg: 640x640 1 Statue of King Ramses II Luxor Temple, 12.2ms
# Speed: 4.4ms preprocess, 12.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_IMG_20250425_142932_jpg.rf.0ab4a171716025f0bd3feeb97a189a25.jpg: 640x640 1 Colossal Statue of Middle Kingdom King, 13.6ms
# Speed: 5.7ms preprocess, 13.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_images-5-_jpg.rf.9d4bbfba42541dc9936e39eb72e510ca.jpg: 640x640 1 King Thutmose III, 14.9ms
# Speed: 4.3ms preprocess, 14.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_images-45-_jpg.rf.8e0ca2e23c8fe59ee7e328b59d265f8b.jpg: 640x640 1 Mask of Tutankhamun, 11.9ms
# Speed: 4.4ms preprocess, 11.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_images-24-_jpg.rf.ffc2408aaf74fc958d6631caa11e6913.jpg: 640x640 1 King Thutmose III, 17.5ms
# Speed: 8.7ms preprocess, 17.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_images-4-_jpg.rf.94a4dcf2fae831cb7aec5440651fed3d.jpg: 640x640 1 Mask of Tutankhamun, 13.4ms
# Speed: 4.4ms preprocess, 13.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_118_jpeg.rf.8e1ce2ede828ec1330030b8903c86e25.jpg: 640x640 2 Colossoi of Memnons, 13.5ms
# Speed: 7.0ms preprocess, 13.5ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_images-30-_jpg.rf.79c26eaf961a3adf1288c32ae6f9c7c7.jpg: 640x640 1 Mask of Tutankhamun, 15.5ms
# Speed: 4.9ms preprocess, 15.5ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_Amenophis_III_British_Musem_c_jpg.rf.ca3952d8b2d21ed1a57c96844c1733a7.jpg: 640x640 1 Amenhotep III, 14.2ms
# Speed: 4.5ms preprocess, 14.2ms inference, 4.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_images-63-_jpg.rf.c517e2700e67bb38447ba171daa43a7b.jpg: 640x640 1 Mask of Tutankhamun, 15.1ms
# Speed: 4.9ms preprocess, 15.1ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_51_jpg.rf.33ec1a81c5a099de6f7b9ab7fc4ec281.jpg: 640x640 1 Hatshepsut face, 16.1ms
# Speed: 4.3ms preprocess, 16.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_A-72_jpg.rf.880d9e92141c8667bd255cb02026fb9c.jpg: 640x640 1 Akhenaten, 18.9ms
# Speed: 6.4ms preprocess, 18.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_356_jpg.rf.0f3982ac9fa9bdb335a105e14ac14e7e.jpg: 640x640 1 Great Pyramids of Giza, 11.1ms
# Speed: 4.8ms preprocess, 11.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_images-13-_jpg.rf.1e696e9862071c4a028e561743aeeb7e.jpg: 640x640 1 Head Statue of Amenhotep iii, 10.5ms
# Speed: 4.8ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_7731634374_fe4e21a493_m_jpg.rf.34bcf4da96cb1357640c649a161935fd.jpg: 640x640 1 Akhenaten, 10.6ms
# Speed: 4.2ms preprocess, 10.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_IMG_20250425_145626_jpg.rf.7ea78f34b317424d1d46cdce23e90d4f.jpg: 640x640 1 Obelsik Tip of Hatshepsut, 10.8ms
# Speed: 4.1ms preprocess, 10.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_A-20_jpg.rf.977023c0755666f210bdf1c9fb4799b7.jpg: 640x640 1 Isis with her child, 10.4ms
# Speed: 4.6ms preprocess, 10.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_WhatsApp-Image-2023-05-16-at-18-50-02-1-_jpeg.rf.862f652a68841d61b51b78901da48413.jpg: 640x640 1 Standing Statue of King Ramses II, 11.0ms
# Speed: 4.8ms preprocess, 11.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_A-36_jpg.rf.055c7cf2d0e6f8381cf214509f1d99da.jpg: 640x640 1 Akhenaten, 10.6ms
# Speed: 4.4ms preprocess, 10.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_A-34_jpg.rf.04199c56abbcdffffb2a053366050816.jpg: 640x640 1 Akhenaten, 10.9ms
# Speed: 4.6ms preprocess, 10.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_54_jpg.rf.fbe3c9d0c987d643708247741c70470c.jpg: 640x640 1 Pyramid of Djoser, 10.7ms
# Speed: 4.6ms preprocess, 10.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_52800901205_73bc1e2849_m_jpg.rf.9648c65aae95c0b6e4bee1f117c2c0cf.jpg: 640x640 1 Statue of King Zoser, 10.5ms
# Speed: 4.5ms preprocess, 10.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_14_jpg.rf.c58fa089b9ac87a43e3800781c44ec11.jpg: 640x640 2 Colossoi of Memnons, 10.0ms
# Speed: 4.4ms preprocess, 10.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_21_jpg.rf.0099b413fbede15e9fb6915518ea155e.jpg: 640x640 1 Nefertiti, 10.6ms
# Speed: 4.7ms preprocess, 10.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_N-47_jpg.rf.a91fc902aaee624780a78641c1208481.jpg: 640x640 1 Nefertiti, 10.6ms
# Speed: 4.6ms preprocess, 10.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_A-22_jpg.rf.ef73f9ca475167386a7f9d5f6ed0119c.jpg: 640x640 1 Amenhotep III, 12.7ms
# Speed: 4.5ms preprocess, 12.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_1_jpg.rf.dbf440d24b116cf021727851d154c492.jpg: 640x640 1 Hatshepsut face, 10.1ms
# Speed: 4.7ms preprocess, 10.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_5_jpg.rf.4486a4cfb0c33f44a1a04df4bd7e7155.jpg: 640x640 2 Colossoi of Memnons, 10.5ms
# Speed: 4.6ms preprocess, 10.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_A-74_jpg.rf.fcd057a2de1b7c14e8bb033e372d3646.jpg: 640x640 1 Isis with her child, 10.5ms
# Speed: 4.8ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# ...
# Speed: 4.2ms preprocess, 12.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_2-3-_jpg.rf.dc7b56250a58bb41227ef2af995950bc.jpg: 640x640 1 Great Pyramids of Giza, 11.5ms
# Speed: 4.1ms preprocess, 11.5ms inference, 5.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_22_jpg.rf.d84765554740c303b79b47722ec32d3a.jpg: 640x640 1 Menkaure Statue, 16.8ms
# Speed: 4.1ms preprocess, 16.8ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_51_jpg.rf.1ae6d48d046dd149b2b4110c34f8fa1d.jpg: 640x640 1 Pyramid of Djoser, 13.6ms
# Speed: 4.1ms preprocess, 13.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_images-37-_jpg.rf.e0a77030848c4b5ee01a51ac48bd5277.jpg: 640x640 2 Colossoi of Memnons, 15.6ms
# Speed: 7.4ms preprocess, 15.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_images-46-_jpg.rf.188253a9908e2511274065eecd55c708.jpg: 640x640 1 Bent Pyramid of King Sneferu, 11.6ms
# Speed: 4.8ms preprocess, 11.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_52087073693_2eda51181a_m_jpg.rf.a3c341045dec611018901704bce5331a.jpg: 640x640 1 Statue of King Zoser, 19.6ms
# Speed: 4.1ms preprocess, 19.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_51_jpg.rf.2087cbbf186c5134b38a93928d1edab6.jpg: 640x640 1 bust of Ramesses II, 17.4ms
# Speed: 4.3ms preprocess, 17.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_IMG_20250425_143501_jpg.rf.b57ad9b5a8917a5f6812fb3b9fe8b501.jpg: 640x640 1 Seated Statue of Amenhotep III, 11.0ms
# Speed: 4.2ms preprocess, 11.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_20250414_143318_jpg.rf.3ceec7d264bdd59d4383e0fa382121c8.jpg: 640x640 1 Colossal Statue of Hormoheb, 11.0ms
# Speed: 4.6ms preprocess, 11.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_51_jpg.rf.e9dea90871ea97dacc51f2129fb31ec7.jpg: 640x640 1 Statue of King Ramses II Luxor Temple, 10.9ms
# Speed: 4.3ms preprocess, 10.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_86_jpg.rf.c1c828fa4fab08d0c61d4292bd398729.jpg: 640x640 1 Mask of Tutankhamun, 10.3ms
# Speed: 4.5ms preprocess, 10.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_A-15_jpg.rf.c7773907c75cc59ee821632973cfbedd.jpg: 640x640 1 Isis with her child, 11.8ms
# Speed: 4.4ms preprocess, 11.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_8_jpg.rf.cbd802fca4e8afc15ba2a28c1a0656f6.jpg: 640x640 1 Amenhotep III and Tiye, 11.8ms
# Speed: 5.0ms preprocess, 11.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_95_jpg.rf.ddceceeee0665d9e894918a6ca9cc4d3.jpg: 640x640 1 Sphinx, 9.9ms
# Speed: 3.9ms preprocess, 9.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_images-26-_jpeg.rf.5bfb6a5523ea432d20858b13b41372f3.jpg: 640x640 1 Statue of King Zoser, 10.2ms
# Speed: 4.3ms preprocess, 10.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_42_jpg.rf.9c3c001a09cb679cdd627f96960349a1.jpg: 640x640 1 Statue of King Ramses II Grand Egyptian Museum, 10.0ms
# Speed: 4.4ms preprocess, 10.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_images-43-_jpg.rf.f94d9a1493b8b235b783388287f7636f.jpg: 640x640 1 bust of Ramesses II, 10.1ms
# Speed: 4.6ms preprocess, 10.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_A-61_jpg.rf.7c9d8ac192904c07c41b56a70691df58.jpg: 640x640 1 Isis with her child, 10.4ms
# Speed: 4.5ms preprocess, 10.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_A-66_jpg.rf.4ad86f3260cad793c9aaf642a4f5922e.jpg: 640x640 1 Akhenaten, 9.7ms
# Speed: 4.4ms preprocess, 9.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_IMG_1106_jpg.rf.7af39f9dd319b0b78bf17e3306bafb28.jpg: 640x640 1 Statue of Khafre, 10.5ms
# Speed: 3.9ms preprocess, 10.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_A-81_jpg.rf.776738e003f64b407fdfb89d877527ce.jpg: 640x640 1 Isis with her child, 10.1ms
# Speed: 4.4ms preprocess, 10.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_26_jpg.rf.826af9277f34e4d94d93f353d796f54a.jpg: 640x640 2 Colossoi of Memnons, 10.2ms
# Speed: 4.5ms preprocess, 10.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_35_jpg.rf.45d96c0c7fc0013c6a1e9f426c85d0a5.jpg: 640x640 1 bust of Ramesses II, 10.3ms
# Speed: 4.4ms preprocess, 10.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_69_jpg.rf.58f57025f506949bb05a4fdba2caf916.jpg: 640x640 1 Statue of King Ramses II Luxor Temple, 9.6ms
# Speed: 4.6ms preprocess, 9.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_IMG_20250425_165501_jpg.rf.c3c11815a128e2a3be0ff4a6eb2ec600.jpg: 640x640 1 Statue of Snefru, 10.0ms
# Speed: 4.0ms preprocess, 10.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_25_jpg.rf.ba7c706c39dc3e5b0488871d904f293e.jpg: 640x640 1 Sphinx of Kings Ramesses ll - Merenptah, 11.0ms
# Speed: 4.5ms preprocess, 11.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_40_jpg.rf.258c6be31c4230f64f4f2b82b2c8149c.jpg: 640x640 1 Hatshepsut face, 10.2ms
# Speed: 4.5ms preprocess, 10.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_images-15-_jpg.rf.7df64f6585e7007023c214818a479b86.jpg: 640x640 1 Isis with her child, 10.9ms
# Speed: 4.5ms preprocess, 10.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_40_jpg.rf.f19f29a50982d20e1b81d76fe34eb6ff.jpg: 640x640 1 Hatshepsut face, 10.2ms
# Speed: 4.3ms preprocess, 10.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_OIP-2023-05-28T175741-859_jpeg.rf.e4ba7404508dc0178105f4b24afbc577.jpg: 640x640 1 Bent Pyramid of King Sneferu, 11.3ms
# Speed: 4.4ms preprocess, 11.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_28_jpg.rf.3fd9fafe46bdb51184338ed31b1fdc4f.jpg: 640x640 1 Statue of God Ptah Ramesses ll Goddess Sekhmet, 10.8ms
# Speed: 4.7ms preprocess, 10.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_WhatsApp-Image-2023-05-16-at-18-49-38-1-_jpeg.rf.199062c8c2ea6406b201f06581d53fb4.jpg: 640x640 1 Standing Statue of King Ramses II, 11.2ms
# Speed: 4.7ms preprocess, 11.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_images-45-_jpg.rf.5ae0fa093722c820658f2b3b2d4decef.jpg: 640x640 1 Nefertiti, 11.3ms
# Speed: 4.1ms preprocess, 11.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_67-1-_jpg.rf.d775a5ccddeed58fe7f6a7583f17bcb1.jpg: 640x640 1 Colossoi of Memnon, 12.9ms
# Speed: 4.4ms preprocess, 12.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_51_jpg.rf.487b0c358a75cddf63333492e059b74c.jpg: 640x640 1 Amenhotep III and Tiye, 1 Amenhotep III, 10.7ms
# Speed: 4.4ms preprocess, 10.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_images-40-_jpg.rf.7840a5673f748fe9df37176dafa02d7a.jpg: 640x640 1 bust of Ramesses II, 11.0ms
# Speed: 4.4ms preprocess, 11.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_download-4-_jpg.rf.83f50bfabf255d7bddc1c41209e3b55d.jpg: 640x640 1 Nefertiti, 11.0ms
# Speed: 4.5ms preprocess, 11.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_images-13-_jpeg.rf.6cd4020e0631d47abc234e203de1ec38.jpg: 640x640 1 Sphinx, 9.6ms
# Speed: 4.3ms preprocess, 9.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_280_jpg.rf.7d11e959e9a8508fdcbe7563d715b048.jpg: 640x640 1 Great Pyramids of Giza, 9.7ms
# Speed: 4.3ms preprocess, 9.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_images-32-_jpeg.rf.25a6766eaafb1c94fee7e4b96fd322cc.jpg: 640x640 1 King Thutmose III, 10.1ms
# Speed: 4.4ms preprocess, 10.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_images-10-_jpeg.rf.b44db352fca3be8736c723aa4cbc0c8d.jpg: 640x640 1 Statue of King Zoser, 10.2ms
# Speed: 4.4ms preprocess, 10.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_images-72-_jpg.rf.d3767d18ab69953e1a6bb7507cbf69ff.jpg: 640x640 2 Colossoi of Memnons, 10.1ms
# Speed: 4.5ms preprocess, 10.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_22_jpg.rf.df718998a07792990d0e7506cc328ece.jpg: 640x640 1 Mask of Tutankhamun, 10.0ms
# Speed: 4.4ms preprocess, 10.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_39_jpg.rf.40c685e5a144a0047e4b42d69a5227c1.jpg: 640x640 1 Nefertiti, 9.6ms
# Speed: 4.2ms preprocess, 9.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_18_jpg.rf.360f74f7b41b15395e76a8fa2e9f3c73.jpg: 640x640 1 Bent Pyramid of King Sneferu, 10.0ms
# Speed: 4.4ms preprocess, 10.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_A-78_jpg.rf.9f4c7cc597ade0702424111cfb7e687f.jpg: 640x640 1 Isis with her child, 10.4ms
# Speed: 4.5ms preprocess, 10.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_N-43_jpg.rf.4730871eac3970041d1095ca17e13f77.jpg: 640x640 1 Nefertiti, 10.3ms
# Speed: 4.4ms preprocess, 10.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_A-22_jpg.rf.5f65b46081f19eafd649160e95364ce3.jpg: 640x640 1 Isis with her child, 10.7ms
# Speed: 4.4ms preprocess, 10.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_images-10-_jpg.rf.f8754b7096c71575a26f8c820f410783.jpg: 640x640 2 Head Statue of Amenhotep iiis, 9.7ms
# Speed: 4.1ms preprocess, 9.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_14_jpg.rf.acf9fff16bf8ef46dd7a1fd0c3b7b505.jpg: 640x640 1 Colossal Statue of King Senwosret IlI, 10.3ms
# Speed: 4.3ms preprocess, 10.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_IMG_20250425_165516_jpg.rf.4575524fcd979f4605e3a35e4dabf497.jpg: 640x640 1 Statue of Snefru, 10.8ms
# Speed: 4.4ms preprocess, 10.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_10_jpg.rf.b400a251147f22cef8cefde8a257a333.jpg: 640x640 1 Colossal Statue of Queen Hatshepsut, 10.4ms
# Speed: 4.5ms preprocess, 10.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_35_jpg.rf.8bedecc89a79b40acf1c3e34b3f7b639.jpg: 640x640 1 Colossal Statue of King Senwosret IlI, 9.7ms
# Speed: 4.1ms preprocess, 9.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_A-69_jpg.rf.ec7c709b727ef1061a3d844e33e27936.jpg: 640x640 1 Akhenaten, 10.9ms
# Speed: 4.1ms preprocess, 10.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_images-19-_jpg.rf.4d305cf5e940df5a66c03d74b6a08c1e.jpg: 640x640 1 King Thutmose III, 10.4ms
# Speed: 4.6ms preprocess, 10.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_images-44-_jpg.rf.dccba87dc62ad866eb1188c27c9ad858.jpg: 640x640 1 Pyramid of Djoser, 15.2ms
# Speed: 5.5ms preprocess, 15.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_54_jpg.rf.011680a6fd55b3e29b9d2c4a3ca8d81d.jpg: 640x640 1 bust of Ramesses II, 10.2ms
# Speed: 3.5ms preprocess, 10.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_66_jpg.rf.f33220b75f2ec3179cd868a037d568f0.jpg: 640x640 1 bust of Ramesses II, 10.0ms
# Speed: 4.0ms preprocess, 10.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_22-3-_jpg.rf.4256045f074293d46abc98f83b8563aa.jpg: 640x640 1 Great Pyramids of Giza, 12.6ms
# Speed: 4.6ms preprocess, 12.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/4_46-2-_jpg.rf.203ead7e45e104e49b1f560e995e88c8.jpg: 640x640 1 Great Pyramids of Giza, 11.7ms
# Speed: 7.3ms preprocess, 11.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_23_jpg.rf.c1a93c45f53abb0cd274c06b0409c705.jpg: 640x640 1 Mask of Tutankhamun, 13.7ms
# Speed: 4.4ms preprocess, 13.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_A-46_jpg.rf.deb2d7f07582a7b75262bff5f51b0a8e.jpg: 640x640 1 Akhenaten, 10.3ms
# Speed: 5.0ms preprocess, 10.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/1_IMG_1065_jpg.rf.03511e4a7fc18c9685a45b13f1199510.jpg: 640x640 1 Statue of Khafre, 10.2ms
# Speed: 3.9ms preprocess, 10.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/3_70_jpg.rf.90375cdf16b8cd75a0eb46738782540e.jpg: 640x640 1 Great Pyramids of Giza, 13.3ms
# Speed: 4.3ms preprocess, 13.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/Merged_Top20_YOLO/images/test/2_24-1-_jpg.rf.baf171be8ff40f06c93a2bb114ae3226.jpg: 640x640 1 Sphinx, 10.8ms
# Speed: 4.4ms preprocess, 10.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Cropping done for /content/Merged_Top20_YOLO/images/test → saved to egypt_cropped/test

# %%
# !zip -r /content/Merged_Top20_YOLO/images.zip /content/Merged_Top20_YOLO/images
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: content/Merged_Top20_YOLO/images/train/1_74_jpg.rf.2487f1853457fb2d66ff393e71bf8408.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/3_20250414_143242_jpg.rf.dbcc128205bc863a3fe1c82df1cce66b.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/2_IMG_1101_jpg.rf.7c105fc13745c40b7d87561cf8d37ce0.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/2_download-13-_jpg.rf.79d0515a81cc49f0f44d65cae17f9f85.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/4_IMG_20250425_142934_jpg.rf.8431fde8a80f6d3cbedd841d6d027650.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/3_23_jpg.rf.de7cb975ead16779d53e052f1cb2956e.jpg (deflated 5%)
#   adding: content/Merged_Top20_YOLO/images/train/4_51_jpg.rf.733ac314ae9d14668737950810301b71.jpg (deflated 6%)
#   adding: content/Merged_Top20_YOLO/images/train/1_th-3-_jpeg.rf.12108cf11211d8377fe7b6226419e843.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/1_A-38_jpg.rf.bb51d4a901fbed565ad62005e624921c.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/4_308_jpg.rf.7c6f1629b8e5b309ece6f01e8d641f37.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/1_159_jpg.rf.a281b2763acd6253f81197bbbaa444e9.jpg (deflated 5%)
#   adding: content/Merged_Top20_YOLO/images/train/1_17-3-_jpg.rf.6a5e80ae66153de219a876b3db0e5ba9.jpg (deflated 3%)
#   adding: content/Merged_Top20_YOLO/images/train/2_36_jpg.rf.2282a2e0efcba17d0bcbe3033febfd50.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/4_images-39-_jpg.rf.2caf78a8431479d715d0940dbaba3e29.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/1_images-4-_jpg.rf.4a770acc6b4e55eb1aa62e515db9e5f1.jpg (deflated 10%)
#   adding: content/Merged_Top20_YOLO/images/train/2_download_jpg.rf.2c63384c2fdfa19f8f6846c16b3b0117.jpg (deflated 4%)
#   adding: content/Merged_Top20_YOLO/images/train/1_3_jpg.rf.65a958c9839c65903a12b8241fc02e19.jpg (deflated 8%)
#   adding: content/Merged_Top20_YOLO/images/train/2_A-38_jpg.rf.0f1e050d945aa65a3e298c4073a9f624.jpg (deflated 12%)
#   adding: content/Merged_Top20_YOLO/images/train/3_A-51_jpg.rf.27c76a80ab55a76838a43980f97d248c.jpg (deflated 8%)
#   adding: content/Merged_Top20_YOLO/images/train/1_A-22_jpg.rf.6e23a9653e67797fe05c7021df02936e.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/2_68_jpg.rf.0e037d04671d2524f5ef5b88780396b4.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/2_images-3-_jpg.rf.69c4986660de8b8db27b8765f6c9f0e7.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/1_17_jpg.rf.ac9b9442c58de67d0bf633b56b850ab3.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/4_54_jpg.rf.a902bad1fc38027e08d10b637e3b2880.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/4_24_jpg.rf.8349ca99101d20434a893504a6e34b9a.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/1_images-66-_jpg.rf.0f909c3f6324fe4ad44546f64bd893d5.jpg (deflated 8%)
#   adding: content/Merged_Top20_YOLO/images/train/4_images-24-_jpg.rf.278439d8235197a87144ab6573704ae9.jpg (deflated 19%)
#   adding: content/Merged_Top20_YOLO/images/train/4_9_jpg.rf.e046a5353fe68efe51d0c13a1efd7b47.jpg (deflated 3%)
#   adding: content/Merged_Top20_YOLO/images/train/1_20_jpg.rf.83b6c3214cb55b40d4ef861e82e273ea.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/1_29_jpg.rf.23bae67d1f16e0b9256cf5b65386f481.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/2_89_jpg.rf.d95b75b60ddfdb3c1f33d0bf146fe5bf.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/1_166_jpg.rf.3b176a9d9f4ef5149ac1b40140315105.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/1_109_jpg.rf.19d276a952a149c82d0234a2581fd654.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/3_61_jpg.rf.7270a3dc3ea3f19fea1b1bcc6e6220e4.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/2_A-36_jpg.rf.923b6ebed6811d8abdbcc6920449bdda.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/4_IMG_20250425_150109_jpg.rf.761cdf2fce19e1fc68a1c20b6544a258.jpg (deflated 7%)
#   adding: content/Merged_Top20_YOLO/images/train/3_20_jpg.rf.6f065c5c853ae7cd3d9f1fbe5ba6b6e2.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/2_images-44-_jpeg.rf.deafa1e7358b3e08ad85645af1aebf9a.jpg (deflated 6%)
#   adding: content/Merged_Top20_YOLO/images/train/3_download-7-_jpeg.rf.cc2d1e21b26233f6b72051b6d3ec7886.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/4_86_jpg.rf.8d3d512c45bab3841ae34d3f98f0e0e4.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/4_OIP-18-_jpeg.rf.cd30a82d51a201383c05b6567dcc3e99.jpg (deflated 8%)
#   adding: content/Merged_Top20_YOLO/images/train/2_OIP-2023-05-28T173211-208_jpeg.rf.455bf341750efd0ced38a0ed764f96bc.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/1_images-29-_jpg.rf.6f82599238ea8024dda125434e4dd0cf.jpg (deflated 11%)
#   adding: content/Merged_Top20_YOLO/images/train/4_6_jpg.rf.478a601169bf5818677472010e6400fa.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/2_images-22-_jpg.rf.6e17565c8628fe552ddc7a2b70b1796e.jpg (deflated 5%)
#   adding: content/Merged_Top20_YOLO/images/train/3_17_jpg.rf.2ec64162c18822c8212b95b540676969.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/1_21_jpg.rf.1946c9032e71367d3c8e7e30af5be1f3.jpg (deflated 4%)
#   adding: content/Merged_Top20_YOLO/images/train/1_19281291360_5a49331215_m_jpg.rf.2372caffab25808ace34d70dba03cb14.jpg (deflated 5%)
#   adding: content/Merged_Top20_YOLO/images/train/1_Z-16_jpg.rf.b98879471536e5a83b21ba3ecd1a4ba2.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/3_79-2-_jpg.rf.5f35c41b6d730bc4e74baba1546da31e.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/2_images_jpg.rf.f337ba9e67a82ff162c4cbd1aafdb784.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/3_67_jpg.rf.37a501d3a921b2085b99ca8295bc4223.jpg (deflated 6%)
#   adding: content/Merged_Top20_YOLO/images/train/3_images-48-_jpg.rf.df9b9d5ab252abfba5c1b7971ffdb11c.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/4_OIP-74-_jpeg.rf.54fa644f62d24e21a59aa3cc265d3eed.jpg (deflated 8%)
#   adding: content/Merged_Top20_YOLO/images/train/1_images_jpg.rf.c0abcc1d0ceb5e81faf31f9bef80e6d8.jpg (deflated 3%)
#   adding: content/Merged_Top20_YOLO/images/train/4_27-2-_jpg.rf.e6514a69ef000af99bdead7aa9e8702e.jpg (deflated 24%)
#   adding: content/Merged_Top20_YOLO/images/train/3_79_jpg.rf.d33de303fa75c9fe03b79e81d1c091ff.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/1_52_jpg.rf.1f16d76eeb749b10d440aca8f15595ae.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/2_images-49-_jpg.rf.68f624eea504bcacfeb3f4afac3061b6.jpg (deflated 6%)
#   adding: content/Merged_Top20_YOLO/images/train/3_16_jpg.rf.77bd95132b6ec65e7f7b6af15f1d58bd.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/3_IMG_20250425_170401_jpg.rf.ff43e9db0dfad07c38d08f2b0c7d1a68.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/4_download-10-_jpg.rf.0a73f192b0abd903092d778f20af0e6b.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/4_images-1-_jpeg.rf.a85db9b5eeb6171950052d8a330a4fff.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/3_640px-Colossal_Statue_of_Amenhotep_III_Reinscribed_by_Merneptah_MET_51268_jpg.rf.9cfa3c3bc4aacdf325e2fc2c7114370b.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/3_images-41-_jpeg.rf.c06b52db661f993ebb62ea11eee9bfc4.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/2_A-53_jpg.rf.7c6338083806705d095d99940964f726.jpg (deflated 13%)
#   adding: content/Merged_Top20_YOLO/images/train/2_360_jpg.rf.a13537275af9b31112815815b12924f1.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/1_A-19_jpg.rf.101998c46e506a4fd9b5915573440b1a.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/4_78_jpg.rf.de56823b0a7e7b4208a33d8e765c0edb.jpg (deflated 5%)
#   adding: content/Merged_Top20_YOLO/images/train/1_IMG_20250425_165656_jpg.rf.56273147be7255046e1d11001b10e97d.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/1_77_jpg.rf.00d9446d787dc6c90eb7ce79e8af1427.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/3_images-43-_jpeg.rf.560475c9300b9b039c486fe23c46da4f.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/2_A-78_jpg.rf.78f75872f62ab1de3ac33669b38379ee.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/4_63_jpg.rf.942a944c40d618adf2d7e9339e1ccff6.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/2_download-10-_jpeg.rf.40f8b6aadfa094e820423f174de7e0d2.jpg (deflated 6%)
#   adding: content/Merged_Top20_YOLO/images/train/4_images-24-_jpg.rf.d293648293d042f69dd22ef46aa65c27.jpg (deflated 26%)
#   adding: content/Merged_Top20_YOLO/images/train/2_32_jpg.rf.37dab95a616bd36d3747757fe6facdb2.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/4_10_jpg.rf.26e71c2624ae17359772e72ea253d586.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/4_OIP-2023-05-28T175735-661_jpeg.rf.3e7a91b5fb17dc4c87c456a79d2dfc98.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/2_27-3-_jpg.rf.dee9892b9b840adc737d411c40f11132.jpg (deflated 3%)
#   adding: content/Merged_Top20_YOLO/images/train/3_56_jpg.rf.3fe9df4901db0b39aec4b6b3f473dc80.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/4_14_jpg.rf.01bb0ef038c8d31c7029c20316aaa719.jpg (deflated 8%)
#   adding: content/Merged_Top20_YOLO/images/train/1_IMG_20250425_173116_jpg.rf.3bdcf2ea72b69f58f069c2a86bbc38ef.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/3_images-53-_jpg.rf.59de0b1076824506df7b82f6ae4b6ec2.jpg (deflated 3%)
#   adding: content/Merged_Top20_YOLO/images/train/4_331_jpg.rf.bcdebb15216ff652c1cf88e469f92fd9.jpg (deflated 16%)
#   adding: content/Merged_Top20_YOLO/images/train/4_A-39_jpg.rf.3a5b2fe102035a766f4da540b2bca623.jpg (deflated 3%)
#   adding: content/Merged_Top20_YOLO/images/train/4_47_jpg.rf.365d5e5c09ccf4fc54906e6338a83ce1.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/4_A-42_jpg.rf.0c56f4b48328bd3bcadfa7243f4dc8f1.jpg (deflated 6%)
#   adding: content/Merged_Top20_YOLO/images/train/3_13_jpg.rf.273e510dc5dfe39ea32e27a316b68e98.jpg (deflated 3%)
#   adding: content/Merged_Top20_YOLO/images/train/4_images-16-_jpg.rf.d2d642780ee45f8e2f271d376925e0d5.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/3_21-3-_jpg.rf.67116ce1952ae8d2bd1d87313340e494.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/3_images-22-_jpeg.rf.999d12c02b950355234ace4d09715404.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/2_29_jpg.rf.c138ce8e7791cea6e33de9555732220c.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/3_259_jpg.rf.2e5bbdf79f913cdaaff73b864c6d60d4.jpg (deflated 8%)
#   adding: content/Merged_Top20_YOLO/images/train/4_62_jpg.rf.7945e57e742883947c45b8701beb00ef.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/3_images-50-_jpg.rf.83bc000e7737a9f046f2c159d4190e4d.jpg (deflated 5%)
#   adding: content/Merged_Top20_YOLO/images/train/4_64_jpg.rf.b4b23ec0fe10acff2a69ba2274a6702b.jpg (deflated 12%)
#   adding: content/Merged_Top20_YOLO/images/train/1_68_jpg.rf.a5da26387448acbf4fa05a6e52d94bbe.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/2_48_jpg.rf.2c378943b278ab65efd03951fa3831d1.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/1_36_jpg.rf.af9b1732dfbf7bbd1674d339fc863078.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/2_IMG_20250425_143049_jpg.rf.fd9805e94915fbf96fdfd78813f747e9.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/1_80_jpg.rf.82134fca888011340ac92f8462e1b016.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/3_125_jpg.rf.7bda03ba1b3c8a14a6a8ddc4ee2bccec.jpg (deflated 4%)
#   adding: content/Merged_Top20_YOLO/images/train/1_images-31-_jpg.rf.6ec566c30ca2a22ea256baf9909a7af3.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/4_30_jpg.rf.83b994fdf1db7ba5ac53971bf083366f.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/2_images-30-_jpg.rf.bf8c91e5d1b083ede018fbd482f2ed1f.jpg (deflated 4%)
#   adding: content/Merged_Top20_YOLO/images/train/2_images-50-_jpg.rf.28de57a7b4fe64314c1e46039592cd27.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/3_IMG_20250425_143437_jpg.rf.1f517af3c22caeaa6ec41f1030529455.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/1_15-4-_jpg.rf.5093ee90aec4adff7535cbba08214f68.jpg (deflated 5%)
#   adding: content/Merged_Top20_YOLO/images/train/2_23_jpg.rf.000f87009362fcdbfece842990befdec.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/3_images-47-_jpg.rf.cfb2276bdf8fcd05b9b2e35e02f6e4ca.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/1_70_jpg.rf.1f8696e5984109ee2ed0a4db6411dba5.jpg (deflated 6%)
#   adding: content/Merged_Top20_YOLO/images/train/4_images-3-_jpg.rf.23c1d5fd5ad583cf4ab0a5f9074f3f9b.jpg (deflated 6%)
#   adding: content/Merged_Top20_YOLO/images/train/3_download-16-_jpeg.rf.9d8bb51f3ad3b8b8de508d722b690087.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/4_images-35-_jpg.rf.b76808b7335ba62e35363bcc1b3772c3.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/3_248_jpg.rf.726c576f884cd22720a0d2e3804bad0e.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/1_IMG_20250425_145651_jpg.rf.e0e033d5a134631c2a0a62a17e2aab1d.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/2_A-33_jpg.rf.1cb8a23480294d7271a396dfb76cfe04.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/2_24_jpg.rf.696563f876e58e655c4c9031f934f7e1.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/4_IMG_20250425_143049_jpg.rf.4c07e57ef2f26d82aa9d8b7b3e8795cf.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/1_A-48_jpg.rf.9d01dd9c59bc27fb48dfb6c2de0ff7fa.jpg (deflated 4%)
#   adding: content/Merged_Top20_YOLO/images/train/3_OIP-5-_jpeg.rf.94233c3251a281625d8e772e7531eab9.jpg (deflated 3%)
#   adding: content/Merged_Top20_YOLO/images/train/1_istockphoto-1217213739-612x612_jpg.rf.41d44828a9d65d40ff3d459d79862cb8.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/2_50_jpg.rf.1735f52f8ee503d354b269d39d2332d5.jpg (deflated 4%)
#   adding: content/Merged_Top20_YOLO/images/train/3_images-38-_jpeg.rf.d703f28d6b1ff43f1c6f6152618d3f18.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/4_39_jpg.rf.ee1b3f9eaea50356437cc3d778d06d8e.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/2_download-6-_jpg.rf.7979789a2862250aebccdcafc65ae788.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/3_52087073693_2eda51181a_m_jpg.rf.f51bb0848b2fb60909ac56a5e8d40ecd.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/2_OIP-31-_jpeg.rf.8fab5d2ee2aa53eda95a8fac706c9409.jpg (deflated 6%)
#   adding: content/Merged_Top20_YOLO/images/train/2_120_jpg.rf.8b5d5a2174d1a60188fb68cce744deae.jpg (deflated 4%)
#   adding: content/Merged_Top20_YOLO/images/train/1_images-26-_jpg.rf.14a8f8fc2d3fd2f120bee8d22eda51f8.jpg (deflated 25%)
#   adding: content/Merged_Top20_YOLO/images/train/3_43_jpg.rf.991bfcdb3c36666700600918775a6558.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/3_A-23_jpg.rf.2d4cad7a76a64d0ef964a4fb8841e81c.jpg (deflated 5%)
#   adding: content/Merged_Top20_YOLO/images/train/1_23-1-_jpg.rf.34330ce13f16ca7909c60f30893003b2.jpg (deflated 4%)
#   adding: content/Merged_Top20_YOLO/images/train/2_59_jpg.rf.9ce90a3c59997c08502c3e20b54a4ec7.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/3_40-1-_jpg.rf.f68911c14065456d7d635ba830d987f2.jpg (deflated 7%)
#   adding: content/Merged_Top20_YOLO/images/train/2_101_jpg.rf.406dfacb3f97a05a0e8781430b2ac103.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/1_download-2-_jpeg.rf.cd32c555caa563307e5a9d4193336f1f.jpg (deflated 3%)
#   adding: content/Merged_Top20_YOLO/images/train/4_download_jpg.rf.f9a9b2a4b51284c4b619771fcb2b04fe.jpg (deflated 10%)
#   adding: content/Merged_Top20_YOLO/images/train/1_54-2-_jpg.rf.844057830cfe6e9793449762beab9847.jpg (deflated 3%)
#   adding: content/Merged_Top20_YOLO/images/train/4_A-11_jpg.rf.1a2048fa22fa876e02817da5b1642399.jpg (deflated 8%)
#   adding: content/Merged_Top20_YOLO/images/train/4_download-8-_jpg.rf.8e02db4b08897d8ba2dad2833e3535dc.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/4_images-62-_jpg.rf.8c4a085db4a9baa78da6134b483bb288.jpg (deflated 10%)
#   adding: content/Merged_Top20_YOLO/images/train/2_39_jpg.rf.96fc91bbf100f5a3b7266b0725e4be04.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/4_A-78_jpg.rf.1a197d156909fa5bb278aaf3d05436f2.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/3_images-44-_jpg.rf.6a93349498b3fcad8107219b40e452c1.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/3_images-26-_jpg.rf.34fcc04736c36a9cceb733f92f2540b8.jpg (deflated 24%)
#   adding: content/Merged_Top20_YOLO/images/train/2_84_jpg.rf.33a24fd25497693aed8c88a663d5a413.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/3_32_jpg.rf.a29f346707b590fb0a07ebd55c0a5d22.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/3_63_jpg.rf.3d31edc1c18886550a21b65078d27cdc.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/1_images-17-_jpg.rf.679753a3ec3e5d359966dc38c211d95a.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/1_Z-1_jpg.rf.94c4f80660af8a9966954ed5eb27cfa2.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/2_161_jpg.rf.875da85285aef21768714afd0f9f8be4.jpg (deflated 4%)
#   adding: content/Merged_Top20_YOLO/images/train/1_IMG_20250425_143359_jpg.rf.8b52040987989332f798e1aee1ffcb86.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/1_A-31_jpg.rf.36b3ade0f5b4de41af5e0d26655ddf2d.jpg (deflated 5%)
#   adding: content/Merged_Top20_YOLO/images/train/2_53_jpg.rf.5aca6dcc80070cff8d69b870f816fefe.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/1_istockphoto-1325195643-612x612_jpg.rf.a9e4923be808f109a67db7e1a199fa62.jpg (deflated 5%)
#   adding: content/Merged_Top20_YOLO/images/train/1_89_jpg.rf.df403002737a74f450aabd34120f50b6.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/3_download-9-_jpg.rf.13ed31845c5c12dea883a783c38fa694.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/3_24-2-_jpg.rf.1c79b4dfdf8bed40fef6a4363e0ae5d3.jpg (deflated 4%)
#   adding: content/Merged_Top20_YOLO/images/train/1_download-2-_jpg.rf.91325ef7f662b7232bc06cc052349252.jpg (deflated 8%)
#   adding: content/Merged_Top20_YOLO/images/train/2_67_jpg.rf.20069f47b4eb26c1c25c69edd6c4d13f.jpg (deflated 5%)
#   adding: content/Merged_Top20_YOLO/images/train/2_A-3_jpg.rf.f66232b1f6026970b82f1d5c0662433a.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/4_A-50_jpg.rf.eeb9b2f3d34ada87a050d231fd2ba34f.jpg (deflated 9%)
#   adding: content/Merged_Top20_YOLO/images/train/1_64_jpg.rf.7c6457cabe4e8ef25ca4eed5b5727054.jpg (deflated 14%)
#   adding: content/Merged_Top20_YOLO/images/train/2_7_jpg.rf.d2813723ecaa6ad503e50305814eccdd.jpg (deflated 14%)
#   adding: content/Merged_Top20_YOLO/images/train/3_OIP-15-_jpeg.rf.62c9995b423f2f8efbfea8067e8e1959.jpg (deflated 6%)
#   adding: content/Merged_Top20_YOLO/images/train/2_46_jpg.rf.39e3fc293c3c1bb5d1ccc2dfafe1cb2b.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/4_OIP-2023-05-28T172756-872_jpeg.rf.7ce4212ceee7143cafa91103caab1246.jpg (deflated 8%)
#   adding: content/Merged_Top20_YOLO/images/train/3_images-25-_jpeg.rf.ce67be62add9ca9146e1272f09d09158.jpg (deflated 12%)
#   adding: content/Merged_Top20_YOLO/images/train/1_N-43_jpg.rf.0111cf2b2187f5f2355b49a8f99f6223.jpg (deflated 5%)
#   adding: content/Merged_Top20_YOLO/images/train/1_images-22-_jpg.rf.daa3315695a7bccdce9c103427224eaf.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/4_18_png.rf.ae9aab09e3664e690d615153aa5fce1f.jpg (deflated 3%)
#   adding: content/Merged_Top20_YOLO/images/train/1_A-73_jpg.rf.85795081ddded0cbc966eba970faf2e9.jpg (deflated 18%)
#   adding: content/Merged_Top20_YOLO/images/train/3_30_jpg.rf.c1d1b6ce8971597289fc008b530918fa.jpg (deflated 6%)
#   adding: content/Merged_Top20_YOLO/images/train/3_IMG_20250425_145707_jpg.rf.2295799d6c349efe172042ea32bd98cd.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/2_IMG_20250425_170213_jpg.rf.c8f0eec0f623f8d69f5ddd1828c35b2e.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/2_56_jpg.rf.48b78f83253ef85da25123f8db9fedcd.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/2_IMG_20250425_150029_jpg.rf.aca4223d3b1bb3eead20285f2628c0df.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/3_images-50-_jpg.rf.bbd048a1154138ad8a2c903e2a09fcb8.jpg (deflated 9%)
#   adding: content/Merged_Top20_YOLO/images/train/1_images-27-_jpg.rf.8444e69a28adfc94863f0e5024dba4fd.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/1_images-4-_jpg.rf.5e03a07b6417758b1af98f8610c4b889.jpg (deflated 5%)
#   adding: content/Merged_Top20_YOLO/images/train/1_IMG_20250425_145653_jpg.rf.4c1b0ff5e9bf3faa9ddc791cfedb0c8a.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/4_31_jpg.rf.9fbc68cb5aa4ca007670544b13de757b.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/3_7_jpg.rf.518e6c502d72b4f42bbb87682e37ab4b.jpg (deflated 6%)
#   adding: content/Merged_Top20_YOLO/images/train/4_34_jpg.rf.8a6b4d386f4b660e178407ac3ad39fcb.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/1_189_jpg.rf.5f0e4b793eaea813ff6f792a0209b7d3.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/2_images-19-_jpeg.rf.daf9abe8f9af01fe1de1aa2cd8e54b10.jpg (deflated 4%)
#   adding: content/Merged_Top20_YOLO/images/train/2_images-37-_jpg.rf.18f66b8e5cbd8478803e216c353c2129.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/3_images-28-_jpg.rf.9d5279d8f5d082b1d98ea2296d745d3b.jpg (deflated 10%)
#   adding: content/Merged_Top20_YOLO/images/train/3_27_jpg.rf.11070c6cd86fcd76485ccef3ea78eb99.jpg (deflated 4%)
#   adding: content/Merged_Top20_YOLO/images/train/3_download-10-_jpg.rf.c184680b7ad06f6e410b85f3ee3c717e.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/4_N-16_jpg.rf.975922234f205472148f3aa023da3505.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/1_Z-6_jpg.rf.1e6a2c4a926075de41c1bdd783bc2f2f.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/2_21_jpg.rf.c5aa41875d988be0025e1ba071ef1188.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/2_A-60_jpg.rf.8629022c94ab429232a1e4b31cb362d2.jpg (deflated 3%)
#   adding: content/Merged_Top20_YOLO/images/train/4_IMG_20250425_143342_jpg.rf.0dac333da1e3fbea4668f36ecc314941.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/2_images-35-_jpg.rf.f83b0c730ad73a6b350769660f044d78.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/4_70_jpg.rf.1b13ac6c994d3394a01860a903c0db6f.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/2_download-34-_jpeg.rf.193d53a95308e063ae9b4845435d3baf.jpg (deflated 3%)
#   adding: content/Merged_Top20_YOLO/images/train/3_IMG_20250425_142940_jpg.rf.5ff8519cb8a0e00967540f400fbb111b.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/4_download-1-_jpg.rf.a121ba097564f05374680e182a8a65c5.jpg (deflated 5%)
#   adding: content/Merged_Top20_YOLO/images/train/4_48_jpg.rf.085aee50e4e656a13b37cae976d89516.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/4_A-23_jpg.rf.a0a97eab09d68e59d4f825b605de9ed8.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/3_30_jpg.rf.c174fcabd719a4c793a65931b6d4015d.jpg (deflated 3%)
#   adding: content/Merged_Top20_YOLO/images/train/2_277_jpg.rf.dbb13aaf0deeb39b3ad751bd8a60497f.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/2_20250414_143327_jpg.rf.f285f9dd422aca7c066dea525667045e.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/1_41_jpg.rf.6a18413888437e7e2862be86f63c7f87.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/2_16-3-_jpg.rf.919e3b60a58908752e8cf490f451850a.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/2_31_jpg.rf.d09c95b4933187eb09bdbddc98fb77a4.jpg (deflated 3%)
#   adding: content/Merged_Top20_YOLO/images/train/3_A-16_jpg.rf.37bfc8da51cb833914520d63ca414621.jpg (deflated 10%)
#   adding: content/Merged_Top20_YOLO/images/train/1_Egyptisches_Museum_Kairo_2016-03-29_Djoser_01_jpg.rf.3e6fe0b8689ab769ce6cf3aa0f601ebf.jpg (deflated 3%)
#   adding: content/Merged_Top20_YOLO/images/train/2_180_jpg.rf.87132ed3a8d6d4f198a24834c275e485.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/3_download-5-_jpeg.rf.91150a23ece3234ba9d4e938da204ef4.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/4_39_jpg.rf.1f94701d13f95fa866606b8ac081fa92.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/2_27_jpg.rf.4196171f749a32feb7c5df50d5fcf53c.jpg (deflated 4%)
#   adding: content/Merged_Top20_YOLO/images/train/1_images-9-_jpeg.rf.d86d859906f6587647ed9b5878af88e5.jpg (deflated 9%)
#   adding: content/Merged_Top20_YOLO/images/train/2_23_jpg.rf.1734e4b2530c558c0bafd9d437de113a.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/4_A-58_jpg.rf.d837085a36804c92a72cd82ca79c0aef.jpg (deflated 4%)
#   adding: content/Merged_Top20_YOLO/images/train/2_50_jpg.rf.ddd7aba7cb41237fcc8dfdf62c962571.jpg (deflated 11%)
#   adding: content/Merged_Top20_YOLO/images/train/4_360_jpg.rf.464774405dc36922960484a04a8b5c78.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/4_IMG_20250425_165622_jpg.rf.88c2f71e96e0c13ef5464d82cc66647c.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/2_IMG_1071_jpg.rf.41eecba0d126e7fa1bb14794e22d32fc.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/4_images-12-_jpeg.rf.95ae2bcf4553686eac9a9ca3f067e276.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/2_IMG_20250425_173043_jpg.rf.205290d612e4f1b5a4a144494ed8fd70.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/3_35-1-_jpg.rf.9462c64f482125d6065de0c938aa7d87.jpg (deflated 7%)
#   adding: content/Merged_Top20_YOLO/images/train/2_183_jpg.rf.4a2386ebce28f5eddc26c8205b08c48b.jpg (deflated 5%)
#   adding: content/Merged_Top20_YOLO/images/train/3_images-42-_jpg.rf.a72d6b17ebea3c4f5e1682675ca4d356.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/2_IMG_20250425_170143_jpg.rf.0f964926af8d0faeb189d3093e566c9a.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/1_IMG_20250425_173109_jpg.rf.89596baa9ba659f8fff7dcc4b0d1886f.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/2_62-2-_jpg.rf.21cf24c6d874efc4748a92eddfce5e55.jpg (deflated 9%)
#   adding: content/Merged_Top20_YOLO/images/train/3_37_jpg.rf.0410bbeae0ad3872399a61529fe949fc.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/4_59_jpg.rf.b6a74a5f505430bf4d74590288b5975e.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/2_download-5-_jpg.rf.b3232cd54c82b8ea3b4a9e5d7c677438.jpg (deflated 3%)
#   adding: content/Merged_Top20_YOLO/images/train/1_27_jpg.rf.5aac033ff277c7402f4d5bfeb6fe684b.jpg (deflated 5%)
#   adding: content/Merged_Top20_YOLO/images/train/2_images-18-_jpg.rf.5bfe251fba30f9a468956fb28316279e.jpg (deflated 3%)
#   adding: content/Merged_Top20_YOLO/images/train/3_13_jpg.rf.0194c563fc352367f3d0734fb3b94b90.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/2_download-2-_jpeg.rf.495c111e984d72d311d447236ccedfa1.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/3_51_jpg.rf.5f28be38428032447fdc23143698c442.jpg (deflated 3%)
#   adding: content/Merged_Top20_YOLO/images/train/3_images-42-_jpg.rf.b69011f6eeb2cc64217c63733666061a.jpg (deflated 6%)
#   adding: content/Merged_Top20_YOLO/images/train/3_IMG_1069_jpg.rf.ba1a24bcf27fe8ab97e94eb76294998c.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/4_images-1-_jpg.rf.a3dcca5c4da2c12ec303dcfacfa21dbc.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/4_20-1-_jpg.rf.c74c0af8ff5e1ff005deb86cc5f0c2b1.jpg (deflated 7%)
#   adding: content/Merged_Top20_YOLO/images/train/4_86_jpg.rf.af68adff0df57c870a5ac533be803e08.jpg (deflated 3%)
#   adding: content/Merged_Top20_YOLO/images/train/2_download-8-_jpeg.rf.10bda041eb447ecb2c1d8a4ed8e03800.jpg (deflated 3%)
#   adding: content/Merged_Top20_YOLO/images/train/2_26-1-_jpg.rf.1617de7dd9bdb6edfb71e4050b6ec709.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/3_images-40-_jpg.rf.d46bd0cf0f4d7ba0d173e59a0cc8bf16.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/4_8_jpg.rf.52a7e82002b331d63a39478ae879d7fb.jpg (deflated 16%)
#   adding: content/Merged_Top20_YOLO/images/train/1_images-63-_jpg.rf.35ff6acd9a179563492691bd1af3d9cf.jpg (deflated 21%)
#   adding: content/Merged_Top20_YOLO/images/train/1_N-14_jpg.rf.73f1848babb439c50afbd5bb2ce36351.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/3_IMG_1114_jpg.rf.20a5009d0b576f21fadb66eeddea7bd5.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/4_A-30_jpg.rf.8e421c78e7457a722c17ad829516c2c5.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/4_346_png.rf.4c12e85ee74c2a0f7cf11c4dc191900f.jpg (deflated 3%)
#   adding: content/Merged_Top20_YOLO/images/train/4_images-23-_jpg.rf.e08379bec155ea40196830beaced7494.jpg (deflated 10%)
#   adding: content/Merged_Top20_YOLO/images/train/2_62_jpg.rf.fbc0286df6458e876246dacba8974707.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/2_37_jpg.rf.4cf75dc3a817744bfa74de2fd8bcdd8a.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/1_90_jpg.rf.8eb5cdbf67b2febbb17e8fcbb69d9c0a.jpg (deflated 4%)
#   adding: content/Merged_Top20_YOLO/images/train/1_istockphoto-1196350237-612x612_jpg.rf.df0e621be4be67d215b61e7964e3e27c.jpg (deflated 7%)
#   adding: content/Merged_Top20_YOLO/images/train/1_28_jpg.rf.e32e08b7cecd6f5edf6d92ebe424df04.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/2_29_jpg.rf.adbc900dda13fe7e85aeaeafee2a37fd.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/3_A-28_jpg.rf.4daef768179b64c1b1a3d747e91a8b84.jpg (deflated 4%)
#   adding: content/Merged_Top20_YOLO/images/train/3_41_jpg.rf.05f7b3d1939771fb3e1bc1e7e8351542.jpg (deflated 14%)
#   adding: content/Merged_Top20_YOLO/images/train/3_IMG_20250425_150028_jpg.rf.a392b485e0461ee7178c4791f463783d.jpg (deflated 4%)
#   adding: content/Merged_Top20_YOLO/images/train/3_7-3-_jpg.rf.e6cb85294aa1fb07cabc5b1edb3c4f6d.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/3_images-23-_jpg.rf.bce9bfa8ad1ced8bbf720dd7ac3ede36.jpg (deflated 3%)
#   adding: content/Merged_Top20_YOLO/images/train/4_37_jpg.rf.3291a921257eace5285cdb41d7aa4149.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/1_images-60-_jpg.rf.716c983428af6d56549a0bf8e5859c33.jpg (deflated 3%)
#   adding: content/Merged_Top20_YOLO/images/train/3_images-43-_jpg.rf.81b0f11ec783dcdad0b72432f84736c2.jpg (deflated 4%)
#   adding: content/Merged_Top20_YOLO/images/train/3_OIP-67-_jpeg.rf.7e584b4e4e716e33230060a602ce3f34.jpg (deflated 8%)
#   adding: content/Merged_Top20_YOLO/images/train/3_images-20-_jpg.rf.f0fc0e7318ce042e7ae51913bb9aee35.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/1_35_jpg.rf.fcb7e17461e82f6eee271eba6ad179d7.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/3_download-9-_jpg.rf.b3c2fb65039aefed405de25a4eec8712.jpg (deflated 14%)
#   adding: content/Merged_Top20_YOLO/images/train/4_N-14_jpg.rf.b07a1596613f13941af7bfb029745528.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/2_20250414_143330_jpg.rf.014364e711ae2f920b78ea6b2891ffa6.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/2_29_jpg.rf.bc84d326fd528d290be38ada191cc518.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/3_A-76_jpg.rf.38c7c51116348755dea0600d89d848b6.jpg (deflated 3%)
#   adding: content/Merged_Top20_YOLO/images/train/4_download-9-_jpeg.rf.42c57a186dceb33862f1f182523daef1.jpg (deflated 3%)
#   adding: content/Merged_Top20_YOLO/images/train/2_A-41_jpg.rf.570ff182844f304fa9712a89a9a9a407.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/4_75_jpg.rf.112abb1f2afff99530822f1af53bdc34.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/1_31_jpg.rf.225e89c7a7485b39cd3038e262a9d22c.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/1_N-47_jpg.rf.0c3ed661c9b91d9af375b2e76e48755a.jpg (deflated 5%)
#   adding: content/Merged_Top20_YOLO/images/train/3_images-46-_jpeg.rf.8bb4cb118c742598ded47c4c6e40f479.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/4_7_jpg.rf.2b8d488501628b83aa1ffdd957a094ae.jpg (deflated 5%)
#   adding: content/Merged_Top20_YOLO/images/train/2_304_jpg.rf.fc4b76219e3e2d47e4036722d83fc2e9.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/4_images-22-_jpg.rf.aa42e2f1dfecd633ee49ce8c7c48c15b.jpg (deflated 3%)
#   adding: content/Merged_Top20_YOLO/images/train/1_download-2-_jpeg.rf.67a4733a7a11fce42e099a6a9b6540dc.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/2_19_jpg.rf.9a0d5003177a01ece9205de96c9d6f29.jpg (deflated 3%)
#   adding: content/Merged_Top20_YOLO/images/train/4_167_jpg.rf.644ab9812503227f80ad785f63a92021.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/1_17_jpg.rf.e7ff0d8953c853560172d5bff2d583e8.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/4_A-53_jpg.rf.045aedb9ad010e99f5baee59674fdea0.jpg (deflated 14%)
#   adding: content/Merged_Top20_YOLO/images/train/4_Luxor_Museum_Amenophis_III-_Statue_05_jpg.rf.8e5892a99cd56a01eeea35e46bb92dbf.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/1_images-78-_jpg.rf.fd8e19865dc93eedbb9219debd58c64a.jpg (deflated 3%)
#   adding: content/Merged_Top20_YOLO/images/train/4_64_jpg.rf.88de24c464155eb335576795516853d1.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/3_12_jpg.rf.8f4e66cd04acfb14fb1e8e051f9c0d0c.jpg (deflated 4%)
#   adding: content/Merged_Top20_YOLO/images/train/3_275_jpg.rf.6d1aa9289e1dc296bc7badfb59493f06.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/3_A-88_jpg.rf.296f2934ababfd2d5e8ec9860b414c75.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/1_20250414_143229_jpg.rf.59341eee1d4ea8b65ce234bf664d76f2.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/2_262_jpg.rf.75e829bcb4ca463989343aa6d133e7e2.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/3_10_jpg.rf.4bb300b99e823aa01b5445586f86a167.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/1_55_jpg.rf.5ae08a0dbd5ed1c324d4009e8b4defc4.jpg (deflated 7%)
#   adding: content/Merged_Top20_YOLO/images/train/3_109_jpg.rf.e249f2b93e5c1f93e57eea4ff8c013ed.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/3_9_jpg.rf.0f5f510e52a74bdf33015ca1641ea47e.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/2_download-19-_jpg.rf.790a5055a653cb7b0c5f1fbef372f7de.jpg (deflated 7%)
#   adding: content/Merged_Top20_YOLO/images/train/4_33_jpg.rf.236083bbc5f235defa2f9c464fde54ba.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/1_32_jpg.rf.484c8212a6de6c6eba2db81e9a766d6e.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/1_73_jpg.rf.e0f515a3ec52ae982fb7933e15db492a.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/3_32_jpg.rf.b0ea2b998561a1262ee9824d75642168.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/2_images-15-_jpg.rf.e299ce043b4b43483753d20c808d7c6e.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/3_images-61-_jpg.rf.e8ea6b3cc85e980c3a425f3d32bf581e.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/4_28-1-_jpg.rf.8ec7b73ed6ad1b0b24e1b9cb43be2e28.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/4_images-47-_jpg.rf.e665f278870f407c7facef88f2880ed0.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/1_images-60-_jpg.rf.b33236ac2d3febd7410d14638f61466e.jpg (deflated 9%)
#   adding: content/Merged_Top20_YOLO/images/train/4_A-7_jpg.rf.9ebd8bac98f8e37bb07ab6a84b926603.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/4_IMG_20250425_170331_jpg.rf.ae439a69b0fbdf3304f8af70e81fe80f.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/2_A-54_jpg.rf.03cd06ac11dae174c27c2d155428da6f.jpg (deflated 6%)
#   adding: content/Merged_Top20_YOLO/images/train/3_images-52-_jpg.rf.ccf169244dcc6d1cba3b8d53d6a47972.jpg (deflated 6%)
#   adding: content/Merged_Top20_YOLO/images/train/4_IMG_20250425_173134_jpg.rf.8010ea2b081aeb23558b26447b9864c2.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/3_OIP-91-_jpeg.rf.2195444d710bf48aab911e3a6cde9b62.jpg (deflated 8%)
#   adding: content/Merged_Top20_YOLO/images/train/1_95_jpg.rf.020811767caa6ce5113f7ba8b40755bb.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/2_42_jpg.rf.5a84a23cb67fe052c592899441ff54ee.jpg (deflated 8%)
#   adding: content/Merged_Top20_YOLO/images/train/3_IMG_20250425_142919_jpg.rf.3aa58b3c22f8504a941d2dbab78b4fc5.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/4_20_jpg.rf.ff2e8e2fcc05ad2fd99089f3ffe68b2d.jpg (deflated 14%)
#   adding: content/Merged_Top20_YOLO/images/train/2_62_jpg.rf.0c92d9b254e31827173ff240026fbda5.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/2_T-17_jpg.rf.1c19a23d17c756f612350d9c3ab86804.jpg (deflated 4%)
#   adding: content/Merged_Top20_YOLO/images/train/3_25_jpg.rf.cc889b47a4398b22378c8f5fa8da7fbe.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/3_A-22_jpg.rf.2003d4b4633ce7ad79e52c6a17d6d18a.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/3_images-38-_jpg.rf.8ae9ae2a7b127d38a785d395b82b5381.jpg (deflated 6%)
#   adding: content/Merged_Top20_YOLO/images/train/4_A-55_jpg.rf.30f74ce58c05d7a9495c2e237e31a40d.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/2_9-1-_jpg.rf.75b63f805761ad07b0a2d891abc8d5de.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/4_A-38_jpg.rf.1eff16e543b36acc4f90f295ec8956fb.jpg (deflated 5%)
#   adding: content/Merged_Top20_YOLO/images/train/4_2_jpg.rf.94f255b6e936a2f328f1354532de2599.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/3_29_jpg.rf.52ac50aa08db3a995851c32ac0ce1691.jpg (deflated 9%)
#   adding: content/Merged_Top20_YOLO/images/train/1_59_jpg.rf.5c74c24558e336cd312b0602c7fbfd90.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/1_168_jpg.rf.b771a3e826314401b86241906906dafe.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/4_download-10-_jpg.rf.9e79c4f4fe2cbc6fa26a638add45de4a.jpg (deflated 3%)
#   adding: content/Merged_Top20_YOLO/images/train/3_IMG_20250425_142915_jpg.rf.173b1150b18b21fcca3def79aad031c5.jpg (deflated 4%)
#   adding: content/Merged_Top20_YOLO/images/train/1_36_jpg.rf.618a3b2ee59aa800189abf227efc6244.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/2_28_jpg.rf.babe243db264d6b4ed85ec6172cb65f3.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/3_A-31_jpg.rf.0a517548f1ee7b464afb944659ee20cb.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/4_images-59-_jpg.rf.c0ee89377bc27cb96fe636d941d36754.jpg (deflated 6%)
#   adding: content/Merged_Top20_YOLO/images/train/2_205_jpg.rf.71b318e0310adc3ab47acf16865aa591.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/3_38_jpg.rf.d10c3342ed89492b7388744968711eeb.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/2_IMG_20250425_143419_jpg.rf.8d3b522e8672bbd0fd9a8f17f1936596.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/1_78_jpg.rf.32d9ebd7a70d12543dd5f3219a984991.jpg (deflated 5%)
#   adding: content/Merged_Top20_YOLO/images/train/2_IMG_20250425_150157_jpg.rf.d16d6d25d144f500f4a1b104c155ceed.jpg (deflated 4%)
#   adding: content/Merged_Top20_YOLO/images/train/3_images-71-_jpg.rf.603e46b29fe5353dfadae5ef1fb13c8d.jpg (deflated 3%)
#   adding: content/Merged_Top20_YOLO/images/train/2_images-12-_jpg.rf.8b854e45fd7cbceef44a2711e446f465.jpg (deflated 6%)
#   adding: content/Merged_Top20_YOLO/images/train/1_772_18094_sm_jpg.rf.36c1a71d6fe69cd7252623655cddaef5.jpg (deflated 3%)
#   adding: content/Merged_Top20_YOLO/images/train/4_istockphoto-1196350238-612x612_jpg.rf.dbad9770e063b9a58e27b4191c2d8e59.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/3_323_jpg.rf.1ebcc68d62f2fecf75284c1aea120678.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/1_images-32-1-_jpg.rf.1c5051a74136f3f6a7d0721342f611db.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/3_16-1-_jpg.rf.32bb2c363d9660c8d9f87fe4130d6a46.jpg (deflated 10%)
#   adding: content/Merged_Top20_YOLO/images/train/1_IMG_20250425_170336_jpg.rf.84e7157c0d9fb8032c023984de0d4c01.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/3_download-14-_jpg.rf.6aa3553be905a740915fe386f67b46d9.jpg (deflated 11%)
#   adding: content/Merged_Top20_YOLO/images/train/4_images-31-1-_jpg.rf.1ffc9fd560ef1179538094c6ec9a8a90.jpg (deflated 6%)
#   adding: content/Merged_Top20_YOLO/images/train/4_images-10-_jpeg.rf.db3fd423e2ea61d8c6a469159aac02a3.jpg (deflated 10%)
#   adding: content/Merged_Top20_YOLO/images/train/1_3-1-_jpg.rf.00bbfe28136803d23687466d278827f2.jpg (deflated 4%)
#   adding: content/Merged_Top20_YOLO/images/train/4_IMG_20250425_165619_jpg.rf.d56ddc8d9b7f29cf781471bd28c93622.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/1_images-34-_jpeg.rf.abb8d72d1f687449840487ac2e797c08.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/4_A-70_jpg.rf.591fb22832cfa8fb659e2e38148a2a92.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/3_45-1-_jpg.rf.e236332d2ad7b03e078ec60674f0a456.jpg (deflated 5%)
#   adding: content/Merged_Top20_YOLO/images/train/2_images-64-_jpg.rf.43e2c3c4ddd09e76d936219b65e2f6e3.jpg (deflated 10%)
#   adding: content/Merged_Top20_YOLO/images/train/3_images-3-_jpg.rf.ca88ab519585d26a58d5c4f982ddfff4.jpg (deflated 8%)
#   adding: content/Merged_Top20_YOLO/images/train/4_17_jpg.rf.acb1257b88bb57a635fcf673a5ce4501.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/2_37-4-_jpg.rf.7eae42c7e119aa8cabeb205850926b48.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/1_24_jpg.rf.068cf5645bd59f9999de35ab6a31fa6b.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/3_images-45-_jpg.rf.bff4d0e898eb54a3673630ffd4da91d5.jpg (deflated 9%)
#   adding: content/Merged_Top20_YOLO/images/train/3_2-1-_jpg.rf.b8c9e23b47676cabe1e5cd2a7ba25a93.jpg (deflated 12%)
#   adding: content/Merged_Top20_YOLO/images/train/1_30_jpg.rf.d9b0704559c3d2c9e0a1397f5b7adb86.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/3_A-47_jpg.rf.2008db9c0119ecbc66f7f6f075168843.jpg (deflated 22%)
#   adding: content/Merged_Top20_YOLO/images/train/4_N-26_jpg.rf.872504fa193c8e0962067676fa65c6fe.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/2_45_jpg.rf.922f8aa60ffc44b63170e126e50dc673.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/3_images-9-_jpg.rf.798bdde8932933be194a9288979d0722.jpg (deflated 6%)
#   adding: content/Merged_Top20_YOLO/images/train/2_80-3-_jpg.rf.51fdac8035cb77439e9473df2ba3ea09.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/2_images-18-_jpeg.rf.2167ecf1c14d1920b69c3d38e57bf80f.jpg (deflated 3%)
#   adding: content/Merged_Top20_YOLO/images/train/1_137_jpg.rf.6478a947d3f5586d14c4cc69390b76d5.jpg (deflated 3%)
#   adding: content/Merged_Top20_YOLO/images/train/3_12-3-_jpg.rf.e7468cc336d31af6c439c07b9780664c.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/1_18-2-_jpg.rf.49e0ed5f0dfd752ddb19334c62ee2d16.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/4_T-3_jpg.rf.39810918e500ad360447df7e3b96eb4d.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/4_download-18-_jpeg.rf.365831f54a3b2025cdc465b4c6c0eed2.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/2_50-3-_jpg.rf.653c852f81dfada4da6f8342d0e6d8f8.jpg (deflated 5%)
#   adding: content/Merged_Top20_YOLO/images/train/2_23_jpg.rf.6c00a630b9a1b737ac1a2b554b58f247.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/2_772_18090_sm_jpg.rf.7d070c015182435f910b61b2d1e7f3cf.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/4_44-1-_jpg.rf.ad81777e0832827412ff0a69e1ced0f5.jpg (deflated 15%)
#   adding: content/Merged_Top20_YOLO/images/train/2_28_jpg.rf.0a6f19ccd27f661ace774a335ee17995.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/1_64-1-_jpg.rf.f644cc0b710cb6dc9337464c7e7bd497.jpg (deflated 12%)
#   adding: content/Merged_Top20_YOLO/images/train/2_images-52-_jpg.rf.24e6d18c7b8f2b08b553afe0c619b873.jpg (deflated 4%)
#   adding: content/Merged_Top20_YOLO/images/train/4_images-10-_jpg.rf.36a11d77aa4d31480af869430934d59e.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/3_54_jpg.rf.21eac064157f7e3992d00629fbf8077c.jpg (deflated 3%)
#   adding: content/Merged_Top20_YOLO/images/train/4_284_jpg.rf.766737945e34392ec149a2137c4abc73.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/1_images-19-_jpg.rf.658b4ec2d1a60615a3e1a37a21f8455d.jpg (deflated 4%)
#   adding: content/Merged_Top20_YOLO/images/train/3_7-2-_jpg.rf.7aa631e6241c55712558044281781a74.jpg (deflated 3%)
#   adding: content/Merged_Top20_YOLO/images/train/2_images-12-_jpg.rf.80a673674678cd5ccede88c71d12df75.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/2_30_jpg.rf.35cb4622363eb94abd46b01f44feca50.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/4_images-6-_jpeg.rf.319f5e042fbdd1e3a1493c0170f5caef.jpg (deflated 4%)
#   adding: content/Merged_Top20_YOLO/images/train/4_A-43_jpg.rf.276e71b51abd8a6655d37d820fea2e59.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/1_A-65_jpg.rf.fc693bae224ce69aec5dd5a6d9a2e78f.jpg (deflated 18%)
#   adding: content/Merged_Top20_YOLO/images/train/4_download-3-_jpg.rf.19c1cebe45dbfe8832d01796a406c0ec.jpg (deflated 4%)
#   adding: content/Merged_Top20_YOLO/images/train/4_20250414_143327_jpg.rf.48b5de934c5712fe87ba4a3a9a962454.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/1_A-44_jpg.rf.8549c62f7719f1461f8d59c87c096a82.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/2_IMG_20250425_170424_jpg.rf.f7437c8d8d5792912f117825b31ca374.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/2_A-26_jpg.rf.cf9e83cedb4094b5f661a793633093eb.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/3_26_jpg.rf.556f4c27763dc93e48dffb6d325f1481.jpg (deflated 5%)
#   adding: content/Merged_Top20_YOLO/images/train/2_28_jpg.rf.1e4240cb1ec7e66719b0dad3134dfc0e.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/1_57_jpg.rf.ee0f079860fc576bb7e51444c660be9b.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/4_59_jpg.rf.e139665a2c8121568ee4a98d36342d61.jpg (deflated 4%)
#   adding: content/Merged_Top20_YOLO/images/train/3_images-12-_jpg.rf.21f589ac7f62838c9e586817e4d9e0ce.jpg (deflated 5%)
#   adding: content/Merged_Top20_YOLO/images/train/3_12_jpg.rf.d6a4d7df3d51c1e5f2a35fa997088bb9.jpg (deflated 0%)
# ...
#   adding: content/Merged_Top20_YOLO/images/train/3_308_jpg.rf.42dfcd1f63e2a51289f9daefc001d04a.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/3_A-56_jpg.rf.fc66e9d5f55ddfb9e7c46469aefb120f.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/1_download-8-_jpg.rf.fcd7ea1aaccf9e4f52a2d055c94b0419.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/1_A-71_jpg.rf.87117a3a7c04e1e53a2b2ed3bbe2e587.jpg (deflated 16%)
#   adding: content/Merged_Top20_YOLO/images/train/2_63_jpg.rf.d6b3986406c9e4c444b43bbc0866429c.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/3_images-62-_jpg.rf.2e931b87021008a99932ca25aa9b4382.jpg (deflated 11%)
#   adding: content/Merged_Top20_YOLO/images/train/4_istockphoto-146783592-612x612_jpg.rf.3ce0de52f06c69148250c1fcbafba4b4.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/2_images-26-_jpg.rf.a15db97e3f300ef3cc90c1fc05fa0e96.jpg (deflated 6%)
#   adding: content/Merged_Top20_YOLO/images/train/2_94_jpg.rf.ecd2c181047acc158eccc49b6560217a.jpg (deflated 7%)
#   adding: content/Merged_Top20_YOLO/images/train/3_images-11-_jpeg.rf.129c27d1dd82d6ac1d0d8e5180b8e8d3.jpg (deflated 5%)
#   adding: content/Merged_Top20_YOLO/images/train/2_A-50_jpg.rf.2339158fe9ffe8527f64ed9d1845c1c5.jpg (deflated 4%)
#   adding: content/Merged_Top20_YOLO/images/train/2_OIP-2023-05-28T173254-931_jpeg.rf.ddfe2af0d34cec30ddd4c0fe184323e0.jpg (deflated 7%)
#   adding: content/Merged_Top20_YOLO/images/train/2_11_jpg.rf.0c5d9683cddfae50168418febfc0f310.jpg (deflated 16%)
#   adding: content/Merged_Top20_YOLO/images/train/3_9_jpg.rf.dddde55195591313716cf54c3e9aac67.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/4_images-51-_jpg.rf.9a2111fc140d2ce31839ad12f9d4629f.jpg (deflated 11%)
#   adding: content/Merged_Top20_YOLO/images/train/2_images-9-_jpg.rf.947dc282aa88fdbc4ba142bf21947bf3.jpg (deflated 4%)
#   adding: content/Merged_Top20_YOLO/images/train/4_IMG_1066_jpg.rf.1ea82e62544b3ba75179d7adaf837821.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/4_IMG_20250425_142945_jpg.rf.dc07abf97e2ebe248856873b6cf47bd6.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/4_119_jpg.rf.b41d63e12c98e7e318875dd937832351.jpg (deflated 5%)
#   adding: content/Merged_Top20_YOLO/images/train/2_download-6-_jpg.rf.e4ae105ee7ca7c7b251a7fcce894d0ad.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/3_96_jpg.rf.a9383f88f08d8c3f167c169a87582a86.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/2_7_jpg.rf.f5b4c662252ebdd34c8878955e460f7b.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/1_218_jpg.rf.88857990717dc25abfa415e0a975373c.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/3_44_jpg.rf.40bcb3ab1247a9091a662876ede631e0.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/4_44_jpg.rf.5f6755a35217226f1b5bfd9d0879386c.jpg (deflated 4%)
#   adding: content/Merged_Top20_YOLO/images/train/4_A-80_jpg.rf.b69b504e2d2697f73b32becbefc9dad0.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/3_30_jpg.rf.ff99f6f3229df85dd5e596f7af6c74aa.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/3_IMG_20250425_170327_jpg.rf.3c6dfc1bae414000c568758ee12e70da.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/4_images-51-_jpeg.rf.6f7076e2a7f5b40b3f82adf4a24e54f7.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/2_IMG_20250425_165605_jpg.rf.f4cb44c2e1ed91536b0c69965056f394.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/4_28_jpg.rf.3272914861dc9e571b68ef9b980be741.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/4_116_jpg.rf.5b1e8259e46f0818d15586e8195a7ba9.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/2_84_jpg.rf.74273fa992307dfdfe5994c1bdbf087a.jpg (deflated 5%)
#   adding: content/Merged_Top20_YOLO/images/train/1_22-1-_jpg.rf.57e2d749e49b6ab84b3092ea32a13f69.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/3_29_jpg.rf.83bfeabb801d358f3d06dc4f61574393.jpg (deflated 30%)
#   adding: content/Merged_Top20_YOLO/images/train/1_images-41-_jpeg.rf.607617937e14692d14e9d076ea2dd47b.jpg (deflated 3%)
#   adding: content/Merged_Top20_YOLO/images/train/4_images-35-_jpg.rf.a11bcc6472a5df01f77c84879a6812bd.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/1_A-34_jpg.rf.ec50a544fe4a1b546728c9c7b0f60789.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/3_images-46-_jpeg.rf.028cef6c6dcb33d1854a84f05dadb7e2.jpg (deflated 4%)
#   adding: content/Merged_Top20_YOLO/images/train/1_34_jpg.rf.15b93a28a5f978d227999ffbae510994.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/3_117_jpg.rf.3ea13b5b2cdffeb05e6d6f13c6d9278c.jpg (deflated 3%)
#   adding: content/Merged_Top20_YOLO/images/train/1_images-19-_jpeg.rf.a7b05dbf6149fd4132b1765ed35fd620.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/1_images-27-_jpg.rf.df6abd4358f436736402d66eb2838804.jpg (deflated 16%)
#   adding: content/Merged_Top20_YOLO/images/train/4_209_jpg.rf.256718515529677e3ce78365ac18fc61.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/2_IMG_20250425_170133_jpg.rf.a6c34b89aa7693efbfdb7d0ac74d6f04.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/1_A-66_jpg.rf.03885b3ea59f2970ac3e2c2903759ea7.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/2_74_jpg.rf.782c8c978e5d87ab9562f1c31ef686f9.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/4_images-37-_jpeg.rf.586c2f4502f3d12ff5342caac458d6bc.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/1_11-1-_jpg.rf.0dc25dfe77bddceec1fa8fea33f94c20.jpg (deflated 10%)
#   adding: content/Merged_Top20_YOLO/images/train/3_40_jpg.rf.9713ee79ace62e00daf97bf2fdb6d1b1.jpg (deflated 9%)
#   adding: content/Merged_Top20_YOLO/images/train/4_images-43-_jpg.rf.c3c2d2c3eeb45a1e3a08df1dfcf983d1.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/2_16_jpg.rf.24d3c44c988b9ab94c6e3198d72e0c9a.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/4_242_jpg.rf.ae110932fd815439056a3c88687b46f9.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/4_15_jpg.rf.585f8eaa563b7d64c6059a0601b6fe57.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/1_19-1-_jpg.rf.39f767761da6ffe673651146de69a11e.jpg (deflated 3%)
#   adding: content/Merged_Top20_YOLO/images/train/4_A-35_jpg.rf.ee36c326845b792e4198da4c89d7fc1f.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/1_images-71-_jpg.rf.972460451424cce9a0b031ee8d162b43.jpg (deflated 3%)
#   adding: content/Merged_Top20_YOLO/images/train/1_33_jpg.rf.dc2800dd6273bb95e244a299e33a6667.jpg (deflated 3%)
#   adding: content/Merged_Top20_YOLO/images/train/3_images-34-1-_jpg.rf.ebfa62adb3ed7c48492ad333ef87c0a0.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/3_images-20-_jpg.rf.702f10b72428382c5b8ef271cbe223e4.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/2_istockphoto-121921894-612x612_jpg.rf.bfb8e99e090ec06f95aa16b9eafeff2c.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/1_IMG_20250425_170414_jpg.rf.537b47346056f908494516d2f520ce76.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/1_A-15_jpg.rf.fe0348707b8d49b305f63e664417e445.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/3_images-35-1-_jpg.rf.6b52571ae633ce5f1d70e465be6a74ca.jpg (deflated 3%)
#   adding: content/Merged_Top20_YOLO/images/train/1_153_jpg.rf.8efde6c8d3278cc71358c83187a2d2fe.jpg (deflated 3%)
#   adding: content/Merged_Top20_YOLO/images/train/1_images-8-_jpg.rf.fe0691b25e7e1d74631b88b2f4ead625.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/4_OIP-2023-05-28T173129-008_jpeg.rf.ed1c45803c76749fc898d5ec6d6b67e6.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/3_36_jpg.rf.c789407c0bbbfd7fb8fedbaa5f21f0bb.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/3_183_jpg.rf.ed0258f4de4b3e44884a9d91631dcc1f.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/3_IMG_20250425_173053_jpg.rf.14829d9d6b80511f6536e51b550783d4.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/2_26_jpg.rf.565171cf176ed8cf381a969f3854edab.jpg (deflated 3%)
#   adding: content/Merged_Top20_YOLO/images/train/2_32_jpg.rf.893ca52d89b7de9fab4a61255db28598.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/1_images-50-_jpg.rf.2a76524f2c90a46509f0d8945a8a482b.jpg (deflated 8%)
#   adding: content/Merged_Top20_YOLO/images/train/4_IMG_20250425_143340_jpg.rf.bfacff4c80b0e64e81a787a1a2b993ba.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/3_19281291360_5a49331215_m_jpg.rf.7c3a4f0f0556452883937f7eb02f304c.jpg (deflated 6%)
#   adding: content/Merged_Top20_YOLO/images/train/2_23_jpg.rf.590ef4f370e25ad152e920480f70ffca.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/2_96_jpg.rf.0195cc2d1ee1e6cc1286c686f8b80b82.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/2_download-3-_jpg.rf.aa84d57809e385155cc0d218fb5830be.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/1_bgx97p_jpg.rf.ec037650edb30f4f490ce2040188c342.jpg (deflated 12%)
#   adding: content/Merged_Top20_YOLO/images/train/3_7_jpg.rf.3ceaff97bf82882b2bfcdbd69b9c66d0.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/3_A-36_jpg.rf.ef05262309ea09a21748db5e79ea06bd.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/1_images-50-_jpg.rf.eecb30174649e7236a97d4a52ddbd4fc.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/3_42_JPG.rf.17b58de6a0eb82f31bfec1b510e9e9fd.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/2_80_jpg.rf.758e6dad90137a92993d1f0010ffa389.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/4_16_jpg.rf.7861f8d063186590fb30bb15c67abec4.jpg (deflated 16%)
#   adding: content/Merged_Top20_YOLO/images/train/3_22_jpg.rf.24aaed5a6b6d2dddf2bbc663b74b26fb.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/4_6_jpg.rf.96f77abca767ba3a5e2c0c8f7d7e7738.jpg (deflated 7%)
#   adding: content/Merged_Top20_YOLO/images/train/1_IMG_20250425_143508_jpg.rf.566dde3ed450b53eecb77ae6e25bb67a.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/4_IMG_20250425_145639_jpg.rf.3c64417a1853c20d3edf3e510fa9d2a6.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/2_32_jpg.rf.04a414d374d9f68ae875f2bd60a500a4.jpg (deflated 4%)
#   adding: content/Merged_Top20_YOLO/images/train/3_th-3-_jpeg.rf.0b15f5f483fc657615ca862f203e70fb.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/3_A-31_jpg.rf.f8ed93dcd4730114aa2126c15b52222c.jpg (deflated 5%)
#   adding: content/Merged_Top20_YOLO/images/train/2_download-5-_jpeg.rf.b29166a4e920ad0cc99ffe5a0f3cd9c6.jpg (deflated 5%)
#   adding: content/Merged_Top20_YOLO/images/train/3_A-29_jpg.rf.95a6915c424c24d820ca3bff0db91a35.jpg (deflated 22%)
#   adding: content/Merged_Top20_YOLO/images/train/4_images-17-_jpeg.rf.e62b2699d53cab5d738583f2b9d3300b.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/4_A-54_jpg.rf.8dd9b360d7d89ff0eb3f6f43de637b45.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/2_26_jpg.rf.034324cacbf122a979f98e37bb3e880a.jpg (deflated 5%)
#   adding: content/Merged_Top20_YOLO/images/train/2_34_jpg.rf.88430106d816c60a4a035e1b856cc848.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/3_download-7-_jpeg.rf.0665ab3c22fae8d1595db359607efdc8.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/2_22_jpg.rf.954427582dd9dc0885f2774bdcbf7f59.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/2_30_jpg.rf.a8675d540f523269ba672e6f44480368.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/1_images-15-_jpg.rf.37df4b83fee27fa1b782976350a6e7bf.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/4_93_jpg.rf.6fce7855f6ffc911dcbfd82e1ba3b3fa.jpg (deflated 8%)
#   adding: content/Merged_Top20_YOLO/images/train/2_ezgif-com-gif-maker_jpg.rf.029dad1552500daa9cfa864eb9309999.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/3_IMG_20250425_145639_jpg.rf.6d9b600a48887469777801adc5c28631.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/4_0-3-_jpg.rf.553193e5acf34908d65b019d6c3fc100.jpg (deflated 6%)
#   adding: content/Merged_Top20_YOLO/images/train/1_11_jpg.rf.480b0b9037fb21a970804ed806fe37a1.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/3_A-50_jpg.rf.359a42c18756768a8a0679575e5c8cbf.jpg (deflated 3%)
#   adding: content/Merged_Top20_YOLO/images/train/4_72_jpg.rf.cb2337b6373245f4eaf00e6d0516b8cb.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/4_images-21-_jpg.rf.24bd010439edc95016a4b9dd69abc016.jpg (deflated 4%)
#   adding: content/Merged_Top20_YOLO/images/train/1_284_jpg.rf.3c242f04f196c6adc9d46247ffac5192.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/3_49_jpg.rf.a847127f93c2ce21b495036bc87df3cd.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/3_images-58-_jpg.rf.ce9941ffcd9007076bcef63dc53a0dc9.jpg (deflated 11%)
#   adding: content/Merged_Top20_YOLO/images/train/4_IMG_20250425_145714_jpg.rf.5ed80fae505587d89bc2c5d147ca8af6.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/1_14_jpg.rf.632a5b0b8f035505d0f63baf27cc671f.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/4_61-1-_jpg.rf.a9f64934169bc19ced7e4dea8ab9b2b0.jpg (deflated 9%)
#   adding: content/Merged_Top20_YOLO/images/train/2_images-15-_jpg.rf.86159245985f070a27aec0d3f99c5fc4.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/2_OIP-88-_jpeg.rf.7e4737d4746fe9ba29baa11b0c835fcc.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/2_A-42_jpg.rf.626ad3c0037c836888c8ce3e7ffbff6b.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/2_22_jpg.rf.36a85d1fd71927ed5c7184fa02d06219.jpg (deflated 3%)
#   adding: content/Merged_Top20_YOLO/images/train/3_A-16_jpg.rf.10bc610f8ad11d6ec073cda9dc6f9ed6.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/1_7cf53569c742e3c486edc471fd1983cb_jpg.rf.982a1cd70ddab3f751539fc29faad2d6.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/4_60_jpg.rf.914b70914b635026b287c7e8bfbc98e8.jpg (deflated 5%)
#   adding: content/Merged_Top20_YOLO/images/train/3_images-27-_jpeg.rf.2c26d8dc9c6bb4ac7bb0b21741922f19.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/3_download-5-_jpg.rf.6f95df49007819bc7828454ca33b7b3c.jpg (deflated 7%)
#   adding: content/Merged_Top20_YOLO/images/train/3_16-2-_jpg.rf.3530a1d9165315976ae03bd41c3f7e8b.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/4_30_jpg.rf.45783e4d9e4bc7cb4f5359e3b21c2f73.jpg (deflated 0%)
#   adding: content/Merged_Top20_YOLO/images/train/2_images-46-_jpg.rf.518536ef9db645e574db21f3cc946b69.jpg (deflated 4%)
#   adding: content/Merged_Top20_YOLO/images/train/2_A-56_jpg.rf.6006369270850764049c9b98af6d614f.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/4_103_jpg.rf.51d3449c032f59697a80b3de868964ab.jpg (deflated 3%)
#   adding: content/Merged_Top20_YOLO/images/train/1_18_png.rf.a9628b24e4a903155501e7230dd123f0.jpg (deflated 2%)
#   adding: content/Merged_Top20_YOLO/images/train/3_A-35_jpg.rf.67c3dbfda09eb2cffdf061d9200259a2.jpg (deflated 20%)
#   adding: content/Merged_Top20_YOLO/images/train/3_A-39_jpg.rf.4f07e6518cf9493d6aaacb865ec15370.jpg (deflated 6%)
#   adding: content/Merged_Top20_YOLO/images/train/3_56_jpg.rf.99a49c3ac5a7daee3a2a22cffb130e3c.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/4_IMG_20250425_173052_jpg.rf.a99622b20c192f713133c10b106730ae.jpg (deflated 1%)
#   adding: content/Merged_Top20_YOLO/images/train/4_download-17-_jpg.rf.a98a1a618ef899fd35658907e9e3fb4d.jpg (deflated 0%)

# %%
from google.colab import files
files.download("/content/Merged_Top20_YOLO/images.zip")

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models

# Define the paths to the training and validation data
train_data_dir = 'egypt_cropped/train'
val_data_dir = 'egypt_cropped/test'

# Define image size and batch size
image_size = 224 # Standard for many pre-trained models
batch_size = 32

# Define data transformations for training and validation
train_transforms = transforms.Compose([
    transforms.RandomResizedCrop(image_size),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) # ImageNet standards
])

val_transforms = transforms.Compose([
    transforms.Resize(image_size),
    transforms.CenterCrop(image_size),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# Create datasets
train_dataset = datasets.ImageFolder(train_data_dir, train_transforms)
val_dataset = datasets.ImageFolder(val_data_dir, val_transforms)

# Create dataloaders
train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=2)
val_dataloader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=2)

# Load a pre-trained model (e.g., ResNet18) and modify the final layer
model = models.resnet18(pretrained=True)
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 35) # Assuming 35 classes

# Print model structure to verify the change
print(model)

print("✅ Training environment set up: Datasets, DataLoaders, and Model loaded.")

# %%
from google.colab import files
criterion = nn.CrossEntropyLoss()

# %%
# 1. Determine the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# 2. Define the loss function
criterion = nn.CrossEntropyLoss()

# 3. Define the optimizer
optimizer = optim.Adam(model.parameters(), lr=0.001)

# 4. Move the model to the device
model.to(device)

# 5. Iterate through epochs
epochs = 14# Define the number of epochs
checkpoint_dir = "checkpoints"
os.makedirs(checkpoint_dir, exist_ok=True)

for epoch in range(epochs):
    print(f"Epoch {epoch+1}/{epochs}")
    print("-" * 10)

    # Training phase
    model.train()
    running_loss = 0.0
    for inputs, labels in train_dataloader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad() # Zero the gradients

        outputs = model(inputs) # Forward pass
        loss = criterion(outputs, labels) # Calculate loss

        loss.backward() # Backward pass
        optimizer.step() # Update weights

        running_loss += loss.item() * inputs.size(0)

    if (epoch+1) % 2 == 0 or epoch < epochs:
        # Save checkpoint
        checkpoint = {
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),

        }

        checkpoint_path = f"{checkpoint_dir}/checkpoint_epoch_{epoch + 1}.pth"
        torch.save(checkpoint, checkpoint_path)

        # نضغطه وننزله
        zip_path = f"{checkpoint_path}.zip"
        # !zip -j "$zip_path" "$checkpoint_path"
        files.download(zip_path)

    epoch_loss = running_loss / len(train_dataset)
    print(f"Train Loss: {epoch_loss:.4f}")

    # (Optional) Validation phase
    model.eval()
    running_loss = 0.0
    correct_predictions = 0
    total_predictions = 0

    with torch.no_grad(): # Disable gradient calculation
        for inputs, labels in val_dataloader:
            inputs, labels = inputs.to(device), labels.to(device)

            outputs = model(inputs)
            loss = criterion(outputs, labels)

            running_loss += loss.item() * inputs.size(0)

            _, predicted = torch.max(outputs.data, 1)
            total_predictions += labels.size(0)
            correct_predictions += (predicted == labels).sum().item()

    epoch_loss = running_loss / len(val_dataset)
    accuracy = correct_predictions / total_predictions
    print(f"Val Loss: {epoch_loss:.4f}, Val Accuracy: {accuracy:.4f}")

print("✅ Training finished.")
# Out:
# Using device: cuda
# Epoch 1/14
# ----------
# updating: checkpoint_epoch_1.pth (deflated 8%)
# Train Loss: 1.2623
# Val Loss: 0.6958, Val Accuracy: 0.7925
# Epoch 2/14
# ----------
# updating: checkpoint_epoch_2.pth (deflated 8%)
# Train Loss: 0.7149
# Val Loss: 0.3271, Val Accuracy: 0.9123
# Epoch 3/14
# ----------
# updating: checkpoint_epoch_3.pth (deflated 8%)
# Train Loss: 0.5185
# Val Loss: 0.3692, Val Accuracy: 0.8906
# Epoch 4/14
# ----------
#   adding: checkpoint_epoch_4.pth (deflated 8%)
# Train Loss: 0.4907
# Val Loss: 0.2361, Val Accuracy: 0.9275
# Epoch 5/14
# ----------
#   adding: checkpoint_epoch_5.pth (deflated 8%)
# Train Loss: 0.4056
# Val Loss: 0.2350, Val Accuracy: 0.9224
# Epoch 6/14
# ----------
#   adding: checkpoint_epoch_6.pth (deflated 8%)
# Train Loss: 0.3996
# Val Loss: 0.2001, Val Accuracy: 0.9438
# Epoch 7/14
# ----------
#   adding: checkpoint_epoch_7.pth (deflated 8%)
# Train Loss: 0.3680
# Val Loss: 0.1683, Val Accuracy: 0.9461
# Epoch 8/14
# ----------
#   adding: checkpoint_epoch_8.pth (deflated 8%)
# Train Loss: 0.3378
# Val Loss: 0.1050, Val Accuracy: 0.9728
# Epoch 9/14
# ----------
#   adding: checkpoint_epoch_9.pth (deflated 8%)
# Train Loss: 0.2852
# Val Loss: 0.1185, Val Accuracy: 0.9655
# Epoch 10/14
# ----------
#   adding: checkpoint_epoch_10.pth (deflated 8%)
# Train Loss: 0.2965
# Val Loss: 0.1539, Val Accuracy: 0.9538
# Epoch 11/14
# ----------
#   adding: checkpoint_epoch_11.pth (deflated 8%)
# Train Loss: 0.2852
# Val Loss: 0.1094, Val Accuracy: 0.9694
# Epoch 12/14
# ----------
#   adding: checkpoint_epoch_12.pth (deflated 8%)
# Train Loss: 0.2628
# Val Loss: 0.1250, Val Accuracy: 0.9659
# Epoch 13/14
# ----------
#   adding: checkpoint_epoch_13.pth (deflated 8%)
# Train Loss: 0.2689
# Val Loss: 0.1138, Val Accuracy: 0.9721
# Epoch 14/14
# ----------
#   adding: checkpoint_epoch_14.pth (deflated 8%)
# Train Loss: 0.2533
# Val Loss: 0.1409, Val Accuracy: 0.9616
# ✅ Training finished.

# %% [markdown]
# ## Save Model

# %%
# Define the path to save the model
model_save_path = "/content/egyptian_landmarks_classification_model.pth"

# Save the model's state dictionary
torch.save(model.state_dict(), model_save_path)

print(f"✅ Model saved successfully to {model_save_path}")
# Out:
# ✅ Model saved successfully to /content/egyptian_landmarks_classification_model.pth

# %% [markdown]
# ## Load Model

# %%
# Define the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load the saved model weights
model_save_path = "/content/egyptian_landmarks_classification_model.pth"

# Instantiate the same model architecture used for training (ResNet18)
# Make sure the number of output features matches the number of classes (35)
reloaded_model = models.resnet18(pretrained=False) # No need to load ImageNet weights again
num_ftrs = reloaded_model.fc.in_features
reloaded_model.fc = nn.Linear(num_ftrs, 35) # Set output layer for 35 classes

# Load the saved state dictionary into the model
reloaded_model.load_state_dict(torch.load(model_save_path, map_location=device))

# Move the model to the device
reloaded_model.to(device)

# Set the model to evaluation mode
reloaded_model.eval()

print("✅ Model reloaded successfully and ready for testing!")
# Out:
# The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
# Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
# ✅ Model reloaded successfully and ready for testing!

# %% [markdown]
# ## Test model

# %%
with torch.no_grad(): # Disable gradient calculation
    for inputs, labels in val_dataloader:
        inputs, labels = inputs.to(device), labels.to(device)

        outputs = reloaded_model(inputs)
        loss = criterion(outputs, labels)

        running_loss += loss.item() * inputs.size(0)

        _, predicted = torch.max(outputs.data, 1)
        total_predictions += labels.size(0)
        correct_predictions += (predicted == labels).sum().item()

epoch_loss = running_loss / len(val_dataset)
accuracy = correct_predictions / total_predictions
print(f"Val Loss: {epoch_loss:.4f}, Val Accuracy: {accuracy:.4f}")
# Out:
# Val Loss: 0.2818, Val Accuracy: 0.9616

# %%
with torch.no_grad(): # Disable gradient calculation
    for inputs, labels in train_dataloader:
        inputs, labels = inputs.to(device), labels.to(device)

        outputs = reloaded_model(inputs)
        loss = criterion(outputs, labels)

        running_loss += loss.item() * inputs.size(0)

        _, predicted = torch.max(outputs.data, 1)
        total_predictions += labels.size(0)
        correct_predictions += (predicted == labels).sum().item()

epoch_loss = running_loss / len(val_dataset)
accuracy = correct_predictions / total_predictions
print(f"Val Loss: {epoch_loss:.4f}, Val Accuracy: {accuracy:.4f}")
# Out:
# Val Loss: 1.2601, Val Accuracy: 0.9359

# %% [markdown]
# ## Test Model after upload from device

# %%
running_loss = 0.0
correct_predictions = 0
total_predictions = 0

with torch.no_grad(): # Disable gradient calculation
    for inputs, labels in val_dataloader:
        inputs, labels = inputs.to(device), labels.to(device)

        outputs = reloaded_model(inputs)
        loss = criterion(outputs, labels)

        running_loss += loss.item() * inputs.size(0)

        _, predicted = torch.max(outputs.data, 1)
        total_predictions += labels.size(0)
        correct_predictions += (predicted == labels).sum().item()

epoch_loss = running_loss / len(val_dataset)
accuracy = correct_predictions / total_predictions
print(f"Val Loss: {epoch_loss:.4f}, Val Accuracy: {accuracy:.4f}")
# Out:
# Val Loss: 0.1502, Val Accuracy: 0.9582

# %%
running_loss = 0.0
correct_predictions = 0
total_predictions = 0
with torch.no_grad(): # Disable gradient calculation
    for inputs, labels in train_dataloader:
        inputs, labels = inputs.to(device), labels.to(device)

        outputs = reloaded_model(inputs)
        loss = criterion(outputs, labels)

        running_loss += loss.item() * inputs.size(0)

        _, predicted = torch.max(outputs.data, 1)
        total_predictions += labels.size(0)
        correct_predictions += (predicted == labels).sum().item()

epoch_loss = running_loss / len(val_dataset)
accuracy = correct_predictions / total_predictions
print(f"Val Loss: {epoch_loss:.4f}, Val Accuracy: {accuracy:.4f}")
# Out:
# Val Loss: 1.0371, Val Accuracy: 0.9248
